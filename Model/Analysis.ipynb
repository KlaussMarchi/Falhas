# %%
import torch, torchvision # pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
from sklearn.model_selection import train_test_split, GroupKFold, StratifiedKFold

from PIL import Image
import matplotlib.pyplot as plt
import cv2, os, shutil, glob, json, math, datetime, random, gc, ast
import numpy as np
import pandas as pd
import torch.nn as nn
import seaborn as sns
from time import time
from utils.index import *
from tqdm import tqdm

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import nms

from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SequentialSampler

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

from utils.Plotter.index import Plotter
pd.set_option('display.max_columns', None)

# %%
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    torch.cuda.synchronize()

gc.collect()
print(torch.__version__)              # versão do PyTorch
print(torch.cuda.is_available())      # True se detectou a GPU
print(torch.cuda.get_device_name(0))  # nome da GPU
# Out:
# 2.7.1+cu118
# True
# Quadro P6000

# %%
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    np.random.default_rng(seed=seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print('random seed done')


seed_everything(42)
# Out:
# random seed done

# %%
OPTIONS = json.loads(open('../Task/info.json', 'r').read())
OPTIONS
# Out:
# {'network': 'unet3d_v2',
#  'dataset': 'marlim_opt_2',
#  'img_size': None,
#  'lr': 0.001,
#  'loss': 'dice_focal',
#  'batch_size': 2,
#  'scheduler': 'plateau',
#  'dropout': 0.1,
#  'num_filters': 32}

# %%
IMG_SIZE   = OPTIONS.get('img_size')
BATCH_SIZE = OPTIONS.get('batch_size')
IMG_SIZE, BATCH_SIZE
# Out:
# (None, 2)

# %%
df = pd.read_csv('../Dataset/DataBase.csv')
IMG_SIZE = ast.literal_eval(df['shape'].iloc[0])
print(df.img_path.iloc[0])

OPTIONS['img_size'] = IMG_SIZE
df
# Out:
# /home/grva-mint/Projects/Falhas/Dataset/marlim_opt_2/images/img_0000.npy
#                id   img_min   img_max  img_mean   img_std  msk_min  msk_max  \
# 0    img_0000.npy  0.000000  0.837736  0.500046  0.100416        0        1
# 1    img_0001.npy  0.000000  0.831765  0.500000  0.058973        0        1
# 2    img_0002.npy  0.000000  1.000000  0.493534  0.181497        0        1
# 3    img_0003.npy  0.380998  0.609255  0.500000  0.021397        0        0
# 4    img_0004.npy  0.344379  0.623390  0.500000  0.021758        0        0
# ..            ...       ...       ...       ...       ...      ...      ...
# 215  img_0215.npy  0.000000  1.000000  0.500000  0.082691        0        1
# 216  img_0216.npy  0.000000  1.000000  0.502823  0.215750        0        1
# 217  img_0217.npy  0.000000  1.000000  0.508539  0.237145        0        1
# 218  img_0218.npy  0.000000  1.000000  0.501193  0.200873        0        1
# 219  img_0219.npy  0.000000  1.000000  0.492813  0.168341        0        1
#
#                shape                                           img_path  \
# 0    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 1    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 2    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 3    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 4    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# ..               ...                                                ...
# 215  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 216  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 217  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 218  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 219  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
#
#                                              mask_path
# 0    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 1    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 2    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 3    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 4    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# ..                                                 ...
# 215  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 216  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 217  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 218  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 219  /home/grva-mint/Projects/Falhas/Dataset/marlim...
#
# [220 rows x 10 columns]

# %%
MULTICLASS = False
classes    = 1
classes
# Out:
# 1

# %%
for index in range(3):
    img, msk = np.load(df.iloc[index].img_path), np.load(df.iloc[index].mask_path)
    print(f'img: {np.min(img), np.max(img)}')
    print(f'msk: {np.min(msk), np.max(msk)}')
    showTile(img=img, mask=msk)
# Out:
# img: (np.float32(0.0), np.float32(0.8377361))
# msk: (np.uint8(0), np.uint8(1))
# img: (np.float32(0.0), np.float32(0.83176494))
# msk: (np.uint8(0), np.uint8(1))
# img: (np.float32(0.0), np.float32(1.0))
# msk: (np.uint8(0), np.uint8(1))

# %% [markdown]
# # SPLITS DOS DADOS

# %%
VAL_SIZE  = 0.045454545454545456
TEST_SIZE = 0.045454545454545456
VAL_SIZE  = VAL_SIZE / (1 - TEST_SIZE)

# %%
temp_df, test_df = train_test_split(df, test_size=TEST_SIZE, random_state=42)
train_df, val_df = train_test_split(temp_df, test_size=VAL_SIZE, random_state=42)
del temp_df

OPTIONS['n_images'] = {'total': len(df), 'train': len(train_df), 'val': len(val_df), 'test': len(test_df)}
OPTIONS['n_images']
# Out:
# {'total': 220, 'train': 200, 'val': 10, 'test': 10}

# %% [markdown]
# # MODELO

# %%
from Network.index import ModelNetwork

# %%
model_options = {
    'network': OPTIONS.get('network'),
    'img_size': OPTIONS.get('img_size'),
    'classes': classes,
    'channels': 1,
    'dropout': OPTIONS.get('dropout'),
    'num_filters': OPTIONS.get('num_filters'),
    'lr': OPTIONS.get('lr'),
}

print(model_options)
network = ModelNetwork(**model_options)
network.model
# Out:
# {'network': 'unet3d_v2', 'img_size': (128, 128, 128), 'classes': 1, 'channels': 1, 'dropout': 0.1, 'num_filters': 32, 'lr': 0.001}
# Unet3D_V2(
#   (enc1): EncoderBlock(
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (pool): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (dropout): Dropout3d(p=0.025, inplace=False)
#   )
#   (enc2): EncoderBlock(
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (pool): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (dropout): Dropout3d(p=0.07500000000000001, inplace=False)
#   )
#   (enc3): EncoderBlock(
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (pool): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (dropout): Dropout3d(p=0.15000000000000002, inplace=False)
#   )
#   (enc4): EncoderBlock(
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (pool): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (dropout): Dropout3d(p=0.25, inplace=False)
#   )
#   (bot_conv): Conv3DBlock(
#     (conv1): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (norm1): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#     (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (norm2): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (bot_drop): Dropout3d(p=0.30000000000000004, inplace=False)
#   (bot_dilated): DilatedBottleneck(
#     (blocks): ModuleList(
#       (0): Sequential(
#         (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(2, 2, 2), dilation=(2, 2, 2), bias=False)
#         (1): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(4, 4, 4), dilation=(4, 4, 4), bias=False)
#         (1): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#   )
#   (dec1): DecoderBlock(
#     (up_conv): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (dropout): Dropout3d(p=0.1, inplace=False)
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (dec2): DecoderBlock(
#     (up_conv): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (dropout): Dropout3d(p=0.1, inplace=False)
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (dec3): DecoderBlock(
#     (up_conv): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (dropout): Dropout3d(p=0.1, inplace=False)
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (dec4): DecoderBlock(
#     (up_conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (norm): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (dropout): Dropout3d(p=0.1, inplace=False)
#     (conv_block): Conv3DBlock(
#       (conv1): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm1): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (act1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (norm2): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (act2): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (out_conv): Conv3d(32, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %%
network.classes
# Out:
# 1

# %% [markdown]
# # DATASET

# %%
from torch.utils.data import Dataset
from Transforms.index import Compose

# %%
class CustomDataset(Dataset):
    def __init__(self, df, multiclass=False, augmentations=None):
        self.df = df.reset_index(drop=True)
        self.multiclass = multiclass
        self.augmentor  = Compose(augmentations) if augmentations else None

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        row  = self.df.iloc[index]
        img  = np.load(row.img_path).astype(np.float32)
        mask = np.load(row.mask_path).astype(np.float32)

        if self.augmentor:
            img, mask = self.augmentor(img, mask)

        img_tensor  = torch.tensor(img, dtype=torch.float32).unsqueeze(0)
        mask_tensor = torch.tensor(mask, dtype=torch.long).unsqueeze(0)
        return (img_tensor, mask_tensor)


trainDataset = CustomDataset(
    df=train_df, 
    multiclass=MULTICLASS,
    augmentations=OPTIONS.get('augmentations')
)

valDataset = CustomDataset(
    df=val_df, 
    multiclass=MULTICLASS
)

testDataset = CustomDataset(
    df=test_df, 
    multiclass=MULTICLASS
)

# %% [markdown]
# # DATA LOADER

# %%
from torch.utils.data import DataLoader

# %%
NUM_WORKERS = 2

trainLoader = DataLoader(
    trainDataset, 
    batch_size=BATCH_SIZE, 
    shuffle=True, 
    num_workers=NUM_WORKERS,
    pin_memory=True if torch.cuda.is_available() else False
)

valLoader = DataLoader(
    valDataset, 
    batch_size=BATCH_SIZE, 
    shuffle=False, 
    num_workers=NUM_WORKERS,
    pin_memory=True if torch.cuda.is_available() else False
)

testLoader = DataLoader(
    testDataset, 
    batch_size=BATCH_SIZE, 
    shuffle=False, 
    num_workers=NUM_WORKERS,
    pin_memory=True if torch.cuda.is_available() else False
)

# %%
images, masks = next(iter(trainLoader))
img = images[0].squeeze().cpu().numpy()
msk = masks[0].squeeze().cpu().numpy()

print('xTrain Shape: ', img.shape)
print('yTrain Shape: ', msk.shape)
print('xTrain Range: ', (float(np.min(img)), float(np.max(img))))
print('yTrain Unique:', np.unique(msk).astype(int))

showTile(img)
showTile(img=img, mask=msk)
# Out:
# xTrain Shape:  (128, 128, 128)
# yTrain Shape:  (128, 128, 128)
# xTrain Range:  (0.0, 0.9009076952934265)
# yTrain Unique: [0 1]

# %% [markdown]
# # TREINAMENTO
#
# ### Losses

# %%
from Losses.index import Losses
from EarlyStopping.index import EarlyStopping
from torch import amp
gc.collect()
# Out:
# 19234

# %%
selected_loss = OPTIONS.get('loss')
loss = Losses(selected_loss, multiclass=network.multiclass)
loss
# Out:
# BinaryDiceFocalLoss(
#   (_loss): DiceFocalLoss(
#     (dice): DiceLoss()
#     (focal): FocalLoss()
#   )
# )

# %% [markdown]
# ### Scheduler

# %%
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
class Scheduler:
    def __new__(cls, selected, optimizer):
        if selected == 'plateau':
            return ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)
        
        if selected == 'cosine':
            return CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
        
        return None


scheduler = OPTIONS.get('scheduler')
Scheduler(scheduler, network.optimizer)

# %% [markdown]
# ### Trainer

# %%
class Trainer:
    def __init__(self, network, loss, epochs, scheduler='plateau'):
        self.network  = network
        self.loss     = loss
        self.epochs   = epochs
        self.img_size = network.img_size 
        
        self.scheduler = Scheduler(scheduler, self.network.optimizer)
        self.early_stopping = EarlyStopping(patience=15, mode='max', min_delta=1e-4)

        self.use_amp = False 
        self.scaler  = amp.GradScaler('cuda', enabled=self.use_amp)

    def start(self):
        self.history = []
        
        for epoch in range(1, self.epochs + 1):
            train_loss, train_iou = self.train()
            val_loss, val_iou     = self.evaluate()

            self.history.append({
                'epoch': epoch,
                'train_loss': train_loss, 'val_loss': val_loss,
                'train_iou': train_iou, 'val_iou': val_iou,
                'lr': self.network.optimizer.param_groups[0]['lr'],
            })
            
            self.scheduler.step(val_loss)
            print(self.history[-1])

            with open(f'progress.json', 'w', encoding='utf-8') as file:
                json.dump(self.history[-1], file, ensure_ascii=False, indent=4)
            
            if self.early_stopping.ready(self.network.model, val_iou):
                break
            
        self.early_stopping.restore_best(self.network.model)

    def train(self, loader=trainLoader):
        self.network.model.train()
        self.network.iou.reset()
        train_loss = 0.0

        for (imgs, masks) in loader:
            imgs, masks = imgs.to(self.network.device), masks.to(self.network.device)
            self.network.optimizer.zero_grad()

            # calcular loss
            with amp.autocast('cuda', enabled=self.use_amp):
                logits = self.network.model(imgs)
                loss = self.loss(logits, masks)
            
            train_loss += loss.item()
            self.scaler.scale(loss).backward()

            self.scaler.unscale_(self.network.optimizer)
            torch.nn.utils.clip_grad_norm_(self.network.model.parameters(), max_norm=1.0)

            self.scaler.step(self.network.optimizer)
            self.scaler.update()
            
            # calcular iou
            if self.network.multiclass:
                preds  = torch.argmax(logits, dim=1) 
                target = masks.squeeze(1) if masks.dim() == 5 else masks
                self.network.iou.update(preds, target) 
            else:
                preds = (torch.sigmoid(logits) > 0.5)
                self.network.iou.update(preds, masks.int()) 
        
        # finalizar
        train_loss /= len(loader)
        train_iou  = self.network.iou.compute().item()
        return (train_loss, train_iou)

    def evaluate(self, loader=valLoader):
        self.network.model.eval()
        self.network.iou.reset()
        val_loss = 0.0

        with torch.no_grad():
            for (imgs, masks) in loader:
                imgs, masks = imgs.to(self.network.device), masks.to(self.network.device)

                with amp.autocast('cuda', enabled=self.use_amp):
                    logits = self.network.model(imgs)
                    val_loss += self.loss(logits, masks).item()
                
                if self.network.multiclass:
                    preds  = torch.argmax(logits, dim=1)
                    target = masks.squeeze(1) if masks.dim() == 5 else masks
                    self.network.iou.update(preds, target)
                else:
                    preds = (torch.sigmoid(logits) > 0.5)
                    self.network.iou.update(preds, masks.int())
        
        val_loss /= len(loader)
        val_iou  = self.network.iou.compute().item()
        return (val_loss, val_iou)


trainer = Trainer(network, loss, epochs=100, scheduler=scheduler)
trainer.start()
# Out:
# {'epoch': 1, 'train_loss': 0.9681856501102447, 'val_loss': 0.9001071572303772, 'train_iou': 0.09136787056922913, 'val_iou': 0.18520812690258026, 'lr': 0.001}
# {'epoch': 2, 'train_loss': 0.9147766721248627, 'val_loss': 0.8335209369659424, 'train_iou': 0.1793694645166397, 'val_iou': 0.25673583149909973, 'lr': 0.001}
# (earling stopping) model improved to 0.257
# {'epoch': 3, 'train_loss': 0.8736525464057923, 'val_loss': 0.7654169201850891, 'train_iou': 0.21726378798484802, 'val_iou': 0.30388712882995605, 'lr': 0.001}
# (earling stopping) model improved to 0.304
# {'epoch': 4, 'train_loss': 0.8376591712236404, 'val_loss': 0.7526908397674561, 'train_iou': 0.254861444234848, 'val_iou': 0.3142428696155548, 'lr': 0.001}
# (earling stopping) model improved to 0.314
# {'epoch': 5, 'train_loss': 0.8105346542596817, 'val_loss': 0.7085565447807312, 'train_iou': 0.2798793315887451, 'val_iou': 0.37214726209640503, 'lr': 0.001}
# (earling stopping) model improved to 0.372
# {'epoch': 6, 'train_loss': 0.7775350579619408, 'val_loss': 0.7095649361610412, 'train_iou': 0.30819809436798096, 'val_iou': 0.36590445041656494, 'lr': 0.001}
# {'epoch': 7, 'train_loss': 0.7655029040575028, 'val_loss': 0.6823075413703918, 'train_iou': 0.3275877833366394, 'val_iou': 0.38452181220054626, 'lr': 0.001}
# (earling stopping) model improved to 0.385
# {'epoch': 8, 'train_loss': 0.7534800657629966, 'val_loss': 0.6713619709014893, 'train_iou': 0.33763644099235535, 'val_iou': 0.38942334055900574, 'lr': 0.001}
# (earling stopping) model improved to 0.389
# {'epoch': 9, 'train_loss': 0.7221475774049759, 'val_loss': 0.6764898180961609, 'train_iou': 0.37587469816207886, 'val_iou': 0.3729425072669983, 'lr': 0.001}
# {'epoch': 10, 'train_loss': 0.7034550434350968, 'val_loss': 0.6350485801696777, 'train_iou': 0.3939433693885803, 'val_iou': 0.42894497513771057, 'lr': 0.001}
# (earling stopping) model improved to 0.429
# {'epoch': 11, 'train_loss': 0.6891701863706112, 'val_loss': 0.6071275055408478, 'train_iou': 0.4124673306941986, 'val_iou': 0.45495328307151794, 'lr': 0.001}
# (earling stopping) model improved to 0.455
# {'epoch': 12, 'train_loss': 0.6847218638658523, 'val_loss': 0.5856610059738159, 'train_iou': 0.4254165589809418, 'val_iou': 0.47021010518074036, 'lr': 0.001}
# (earling stopping) model improved to 0.470
# {'epoch': 13, 'train_loss': 0.6700601610541344, 'val_loss': 0.580621600151062, 'train_iou': 0.4352487027645111, 'val_iou': 0.46244752407073975, 'lr': 0.001}
# {'epoch': 14, 'train_loss': 0.6629665650427341, 'val_loss': 0.6145451664924622, 'train_iou': 0.4418432414531708, 'val_iou': 0.45379969477653503, 'lr': 0.001}
# {'epoch': 15, 'train_loss': 0.6473810467123985, 'val_loss': 0.5846358001232147, 'train_iou': 0.4617600440979004, 'val_iou': 0.46036529541015625, 'lr': 0.001}
# {'epoch': 16, 'train_loss': 0.6462660881876946, 'val_loss': 0.5655003070831299, 'train_iou': 0.4604444205760956, 'val_iou': 0.4982960820198059, 'lr': 0.001}
# (earling stopping) model improved to 0.498
# {'epoch': 17, 'train_loss': 0.6317614160478116, 'val_loss': 0.5473950564861297, 'train_iou': 0.48240384459495544, 'val_iou': 0.5183582901954651, 'lr': 0.001}
# (earling stopping) model improved to 0.518
# {'epoch': 18, 'train_loss': 0.6280216354131699, 'val_loss': 0.5414783895015717, 'train_iou': 0.48792311549186707, 'val_iou': 0.5083684325218201, 'lr': 0.001}
# {'epoch': 19, 'train_loss': 0.621375217884779, 'val_loss': 0.5463381111621857, 'train_iou': 0.48946133255958557, 'val_iou': 0.4967935383319855, 'lr': 0.001}
# {'epoch': 20, 'train_loss': 0.6195781588554382, 'val_loss': 0.5588184416294097, 'train_iou': 0.4922739863395691, 'val_iou': 0.5015884637832642, 'lr': 0.001}
# {'epoch': 21, 'train_loss': 0.6087232232093811, 'val_loss': 0.5612223744392395, 'train_iou': 0.5121384859085083, 'val_iou': 0.5022585988044739, 'lr': 0.001}
# {'epoch': 22, 'train_loss': 0.6162704679369927, 'val_loss': 0.5300081849098206, 'train_iou': 0.5007108449935913, 'val_iou': 0.5261954665184021, 'lr': 0.001}
# (earling stopping) model improved to 0.526
# {'epoch': 23, 'train_loss': 0.6034892573952675, 'val_loss': 0.5147965610027313, 'train_iou': 0.516325056552887, 'val_iou': 0.5372666120529175, 'lr': 0.001}
# (earling stopping) model improved to 0.537
# {'epoch': 24, 'train_loss': 0.5996085469424725, 'val_loss': 0.5109888732433319, 'train_iou': 0.5170966386795044, 'val_iou': 0.5432013273239136, 'lr': 0.001}
# (earling stopping) model improved to 0.543
# {'epoch': 25, 'train_loss': 0.5953358297049999, 'val_loss': 0.5297125279903412, 'train_iou': 0.5269514918327332, 'val_iou': 0.5355716943740845, 'lr': 0.001}
# {'epoch': 26, 'train_loss': 0.600488850325346, 'val_loss': 0.528707766532898, 'train_iou': 0.519071638584137, 'val_iou': 0.5275142788887024, 'lr': 0.001}
# {'epoch': 27, 'train_loss': 0.5840134267508984, 'val_loss': 0.5020229130983352, 'train_iou': 0.53603595495224, 'val_iou': 0.5618661046028137, 'lr': 0.001}
# (earling stopping) model improved to 0.562
# {'epoch': 28, 'train_loss': 0.5854472361505032, 'val_loss': 0.4988689512014389, 'train_iou': 0.5410815477371216, 'val_iou': 0.5587238073348999, 'lr': 0.001}
# {'epoch': 29, 'train_loss': 0.5700034233927727, 'val_loss': 0.5002946853637695, 'train_iou': 0.5571333765983582, 'val_iou': 0.5553392171859741, 'lr': 0.001}
# {'epoch': 30, 'train_loss': 0.5723312097787857, 'val_loss': 0.5029318273067475, 'train_iou': 0.5507587790489197, 'val_iou': 0.5583195090293884, 'lr': 0.001}
# {'epoch': 31, 'train_loss': 0.5661814929544926, 'val_loss': 0.5027804911136627, 'train_iou': 0.5609048008918762, 'val_iou': 0.5588916540145874, 'lr': 0.001}
# {'epoch': 32, 'train_loss': 0.5650713995099068, 'val_loss': 0.539752060174942, 'train_iou': 0.5639175772666931, 'val_iou': 0.5198368430137634, 'lr': 0.001}
# {'epoch': 33, 'train_loss': 0.5758916234970093, 'val_loss': 0.4941915810108185, 'train_iou': 0.5479926466941833, 'val_iou': 0.5665589570999146, 'lr': 0.001}
# (earling stopping) model improved to 0.567
# {'epoch': 34, 'train_loss': 0.5628684711456299, 'val_loss': 0.492173445224762, 'train_iou': 0.5702765583992004, 'val_iou': 0.5745781064033508, 'lr': 0.001}
# (earling stopping) model improved to 0.575
# {'epoch': 35, 'train_loss': 0.5613707105815411, 'val_loss': 0.4951048314571381, 'train_iou': 0.5679308772087097, 'val_iou': 0.5662266612052917, 'lr': 0.001}
# {'epoch': 36, 'train_loss': 0.5619848388433456, 'val_loss': 0.47067496180534363, 'train_iou': 0.5715187788009644, 'val_iou': 0.5909701585769653, 'lr': 0.001}
# (earling stopping) model improved to 0.591
# {'epoch': 37, 'train_loss': 0.5563994109630584, 'val_loss': 0.48645026981830597, 'train_iou': 0.5773966312408447, 'val_iou': 0.5790619254112244, 'lr': 0.001}
# {'epoch': 38, 'train_loss': 0.557268041819334, 'val_loss': 0.4663155436515808, 'train_iou': 0.5728392004966736, 'val_iou': 0.5965921878814697, 'lr': 0.001}
# (earling stopping) model improved to 0.597
# {'epoch': 39, 'train_loss': 0.5622243075072766, 'val_loss': 0.5060184836387634, 'train_iou': 0.571036159992218, 'val_iou': 0.556812584400177, 'lr': 0.001}
# {'epoch': 40, 'train_loss': 0.5671889665722847, 'val_loss': 0.5077762305736542, 'train_iou': 0.5638663172721863, 'val_iou': 0.5595465898513794, 'lr': 0.001}
# {'epoch': 41, 'train_loss': 0.5486452223360538, 'val_loss': 0.48121567964553835, 'train_iou': 0.5872476100921631, 'val_iou': 0.5824703574180603, 'lr': 0.001}
# {'epoch': 42, 'train_loss': 0.5588820293545723, 'val_loss': 0.48414591550827024, 'train_iou': 0.5718065500259399, 'val_iou': 0.5868967771530151, 'lr': 0.001}
# {'epoch': 43, 'train_loss': 0.5483787280321121, 'val_loss': 0.4904077023267746, 'train_iou': 0.587862491607666, 'val_iou': 0.5710576176643372, 'lr': 0.001}
# {'epoch': 44, 'train_loss': 0.5451378507912159, 'val_loss': 0.47947502732276914, 'train_iou': 0.5920639634132385, 'val_iou': 0.580329954624176, 'lr': 0.001}
# {'epoch': 45, 'train_loss': 0.5363356669992209, 'val_loss': 0.45655068159103396, 'train_iou': 0.6007944941520691, 'val_iou': 0.6094805598258972, 'lr': 0.001}
# (earling stopping) model improved to 0.609
# {'epoch': 46, 'train_loss': 0.5361942142248154, 'val_loss': 0.49361780285835266, 'train_iou': 0.605003833770752, 'val_iou': 0.57374107837677, 'lr': 0.001}
# {'epoch': 47, 'train_loss': 0.547830159664154, 'val_loss': 0.47813977003097535, 'train_iou': 0.5856660008430481, 'val_iou': 0.5891510248184204, 'lr': 0.001}
# {'epoch': 48, 'train_loss': 0.5386432421207428, 'val_loss': 0.47230565547943115, 'train_iou': 0.599574863910675, 'val_iou': 0.5952426195144653, 'lr': 0.001}
# {'epoch': 49, 'train_loss': 0.5248010037839412, 'val_loss': 0.4500351041555405, 'train_iou': 0.6166503429412842, 'val_iou': 0.6221808195114136, 'lr': 0.001}
# (earling stopping) model improved to 0.622
# {'epoch': 50, 'train_loss': 0.5246451604366302, 'val_loss': 0.4580279588699341, 'train_iou': 0.6183232665061951, 'val_iou': 0.6017176508903503, 'lr': 0.001}
# {'epoch': 51, 'train_loss': 0.5301862358301878, 'val_loss': 0.46552098393440244, 'train_iou': 0.609749972820282, 'val_iou': 0.6073673367500305, 'lr': 0.001}
# {'epoch': 52, 'train_loss': 0.5124118690192699, 'val_loss': 0.4712451368570328, 'train_iou': 0.6347885727882385, 'val_iou': 0.5909838080406189, 'lr': 0.001}
# {'epoch': 53, 'train_loss': 0.527321232482791, 'val_loss': 0.4553757101297379, 'train_iou': 0.6124588847160339, 'val_iou': 0.6204980611801147, 'lr': 0.001}
# {'epoch': 54, 'train_loss': 0.5230160664021969, 'val_loss': 0.44693962335586546, 'train_iou': 0.6190028190612793, 'val_iou': 0.6206230521202087, 'lr': 0.001}
# {'epoch': 55, 'train_loss': 0.5251787300407886, 'val_loss': 0.44699915647506716, 'train_iou': 0.615998387336731, 'val_iou': 0.6257631182670593, 'lr': 0.001}
# (earling stopping) model improved to 0.626
# {'epoch': 56, 'train_loss': 0.5102974580228329, 'val_loss': 0.4511975049972534, 'train_iou': 0.6364841461181641, 'val_iou': 0.6227245330810547, 'lr': 0.001}
# {'epoch': 57, 'train_loss': 0.5236910400539636, 'val_loss': 0.47134979367256163, 'train_iou': 0.619854211807251, 'val_iou': 0.5933502912521362, 'lr': 0.001}
# {'epoch': 58, 'train_loss': 0.5348215368390083, 'val_loss': 0.5065501093864441, 'train_iou': 0.6026543974876404, 'val_iou': 0.5590919852256775, 'lr': 0.001}
# {'epoch': 59, 'train_loss': 0.5134300324320793, 'val_loss': 0.4570134371519089, 'train_iou': 0.6331615447998047, 'val_iou': 0.6118301749229431, 'lr': 0.001}
# {'epoch': 60, 'train_loss': 0.5072263592481613, 'val_loss': 0.4732637882232666, 'train_iou': 0.6389058828353882, 'val_iou': 0.5750958919525146, 'lr': 0.001}
# {'epoch': 61, 'train_loss': 0.5032129336893558, 'val_loss': 0.45583664774894717, 'train_iou': 0.6429950594902039, 'val_iou': 0.6143903732299805, 'lr': 0.001}
# {'epoch': 62, 'train_loss': 0.4993911273032427, 'val_loss': 0.4437071979045868, 'train_iou': 0.6480374932289124, 'val_iou': 0.6311705708503723, 'lr': 0.001}
# (earling stopping) model improved to 0.631
# {'epoch': 63, 'train_loss': 0.49731977909803393, 'val_loss': 0.4417679965496063, 'train_iou': 0.6504249572753906, 'val_iou': 0.633807897567749, 'lr': 0.001}
# (earling stopping) model improved to 0.634
# {'epoch': 64, 'train_loss': 0.49457468450069425, 'val_loss': 0.4359760254621506, 'train_iou': 0.6573122143745422, 'val_iou': 0.6401873230934143, 'lr': 0.001}
# (earling stopping) model improved to 0.640
# {'epoch': 65, 'train_loss': 0.4965039336681366, 'val_loss': 0.4704114019870758, 'train_iou': 0.6529542207717896, 'val_iou': 0.593245804309845, 'lr': 0.001}
# {'epoch': 66, 'train_loss': 0.4926201032102108, 'val_loss': 0.4447324573993683, 'train_iou': 0.6594529151916504, 'val_iou': 0.6300694346427917, 'lr': 0.001}
# {'epoch': 67, 'train_loss': 0.5008278727531433, 'val_loss': 0.4374836504459381, 'train_iou': 0.6473792791366577, 'val_iou': 0.6378894448280334, 'lr': 0.001}
# {'epoch': 68, 'train_loss': 0.4937178771197796, 'val_loss': 0.4391726732254028, 'train_iou': 0.6579652428627014, 'val_iou': 0.6370962262153625, 'lr': 0.001}
# {'epoch': 69, 'train_loss': 0.49129784271121024, 'val_loss': 0.5009002149105072, 'train_iou': 0.6606420278549194, 'val_iou': 0.5769316554069519, 'lr': 0.001}
# {'epoch': 70, 'train_loss': 0.4948803034424782, 'val_loss': 0.4503829270601273, 'train_iou': 0.6551666855812073, 'val_iou': 0.6241825819015503, 'lr': 0.001}
# {'epoch': 71, 'train_loss': 0.512078936547041, 'val_loss': 0.4493937700986862, 'train_iou': 0.6336164474487305, 'val_iou': 0.6223004460334778, 'lr': 0.001}
# {'epoch': 72, 'train_loss': 0.4905560912191868, 'val_loss': 0.46544389128685, 'train_iou': 0.6601320505142212, 'val_iou': 0.6125080585479736, 'lr': 0.001}
# {'epoch': 73, 'train_loss': 0.483541896045208, 'val_loss': 0.4550417274236679, 'train_iou': 0.6707289814949036, 'val_iou': 0.618641197681427, 'lr': 0.001}
# {'epoch': 74, 'train_loss': 0.47642322540283205, 'val_loss': 0.4482158929109573, 'train_iou': 0.6808609962463379, 'val_iou': 0.6242202520370483, 'lr': 0.001}
# {'epoch': 75, 'train_loss': 0.4758738425374031, 'val_loss': 0.4437700092792511, 'train_iou': 0.6797475218772888, 'val_iou': 0.6306043267250061, 'lr': 0.001}
# {'epoch': 76, 'train_loss': 0.4648539277911186, 'val_loss': 0.43214452266693115, 'train_iou': 0.7002077698707581, 'val_iou': 0.6495411396026611, 'lr': 0.0005}
# (earling stopping) model improved to 0.650
# {'epoch': 77, 'train_loss': 0.45120414413511756, 'val_loss': 0.4337844252586365, 'train_iou': 0.7199925780296326, 'val_iou': 0.6438167095184326, 'lr': 0.0005}
# {'epoch': 78, 'train_loss': 0.4490116740018129, 'val_loss': 0.42958762049674987, 'train_iou': 0.7245200276374817, 'val_iou': 0.651866614818573, 'lr': 0.0005}
# (earling stopping) model improved to 0.652
# {'epoch': 79, 'train_loss': 0.4488558039069176, 'val_loss': 0.44582816660404206, 'train_iou': 0.726560115814209, 'val_iou': 0.6351454854011536, 'lr': 0.0005}
# {'epoch': 80, 'train_loss': 0.44738190807402134, 'val_loss': 0.4366080939769745, 'train_iou': 0.7258186936378479, 'val_iou': 0.6485451459884644, 'lr': 0.0005}
# {'epoch': 81, 'train_loss': 0.45376798398792745, 'val_loss': 0.4401708602905273, 'train_iou': 0.718370795249939, 'val_iou': 0.636983335018158, 'lr': 0.0005}
# {'epoch': 82, 'train_loss': 0.44656387366354466, 'val_loss': 0.43597590923309326, 'train_iou': 0.7245544791221619, 'val_iou': 0.6390217542648315, 'lr': 0.0005}
# {'epoch': 83, 'train_loss': 0.44790349662303924, 'val_loss': 0.43712267875671384, 'train_iou': 0.7237960696220398, 'val_iou': 0.6399924159049988, 'lr': 0.0005}
# {'epoch': 84, 'train_loss': 0.4426873417943716, 'val_loss': 0.43862069547176363, 'train_iou': 0.7326110005378723, 'val_iou': 0.6458300948143005, 'lr': 0.0005}
# {'epoch': 85, 'train_loss': 0.4450375535339117, 'val_loss': 0.43332448303699495, 'train_iou': 0.7279344797134399, 'val_iou': 0.6488809585571289, 'lr': 0.0005}
# {'epoch': 86, 'train_loss': 0.4440705344080925, 'val_loss': 0.4369798958301544, 'train_iou': 0.7296926379203796, 'val_iou': 0.6420166492462158, 'lr': 0.0005}
# {'epoch': 87, 'train_loss': 0.43831602066755293, 'val_loss': 0.43652087450027466, 'train_iou': 0.7382835745811462, 'val_iou': 0.6470003724098206, 'lr': 0.0005}
# {'epoch': 88, 'train_loss': 0.4381761112809181, 'val_loss': 0.4311890870332718, 'train_iou': 0.7387651205062866, 'val_iou': 0.6510023474693298, 'lr': 0.0005}
# {'epoch': 89, 'train_loss': 0.44682185031473637, 'val_loss': 0.4396870732307434, 'train_iou': 0.7291936874389648, 'val_iou': 0.6426317095756531, 'lr': 0.0005}
# {'epoch': 90, 'train_loss': 0.42933029897511005, 'val_loss': 0.4322563141584396, 'train_iou': 0.7564993500709534, 'val_iou': 0.6476011872291565, 'lr': 0.00025}
# {'epoch': 91, 'train_loss': 0.42265658609569073, 'val_loss': 0.43312891125679015, 'train_iou': 0.7638634443283081, 'val_iou': 0.6500396132469177, 'lr': 0.00025}
# {'epoch': 92, 'train_loss': 0.4233487992733717, 'val_loss': 0.43210251033306124, 'train_iou': 0.7648220062255859, 'val_iou': 0.6495145559310913, 'lr': 0.00025}
# {'epoch': 93, 'train_loss': 0.4222912897914648, 'val_loss': 0.4244151324033737, 'train_iou': 0.7624562978744507, 'val_iou': 0.6634352803230286, 'lr': 0.00025}
# (earling stopping) model improved to 0.663
# {'epoch': 94, 'train_loss': 0.42112845174968244, 'val_loss': 0.43254340887069703, 'train_iou': 0.7693655490875244, 'val_iou': 0.6525643467903137, 'lr': 0.00025}
# {'epoch': 95, 'train_loss': 0.42000720374286177, 'val_loss': 0.4291118890047073, 'train_iou': 0.7693299651145935, 'val_iou': 0.6554029583930969, 'lr': 0.00025}
# {'epoch': 96, 'train_loss': 0.41600932024419307, 'val_loss': 0.4275843411684036, 'train_iou': 0.7752590775489807, 'val_iou': 0.6539806723594666, 'lr': 0.00025}
# {'epoch': 97, 'train_loss': 0.42002087786793707, 'val_loss': 0.4289322137832642, 'train_iou': 0.7705965638160706, 'val_iou': 0.6554298400878906, 'lr': 0.00025}
# {'epoch': 98, 'train_loss': 0.41611849047243593, 'val_loss': 0.4307577729225159, 'train_iou': 0.7747567892074585, 'val_iou': 0.656664252281189, 'lr': 0.00025}
# {'epoch': 99, 'train_loss': 0.41853135224431753, 'val_loss': 0.4292832434177399, 'train_iou': 0.7731829881668091, 'val_iou': 0.6555878520011902, 'lr': 0.00025}
# {'epoch': 100, 'train_loss': 0.41622020851820707, 'val_loss': 0.43055223524570463, 'train_iou': 0.7757903337478638, 'val_iou': 0.6566246747970581, 'lr': 0.00025}

# %%
def plotModel(history, save=None):
    plt.figure(figsize=(17, 5))
    plt.subplot(1, 2, 1)
    plt.plot([h.get('train_loss')
             for h in history], 'y', label='Training loss')
    plt.plot([h.get('val_loss')
             for h in history], 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('epoch'), plt.ylabel('loss')
    plt.legend(), plt.grid()

    plt.subplot(1, 2, 2)
    plt.plot([h.get('train_iou') for h in history], 'y', label='Training IoU')
    plt.plot([h.get('val_iou') for h in history], 'r', label='Validation IoU')
    plt.title('Training and validation IoU')
    plt.xlabel('epoch'), plt.ylabel('IoU')
    plt.legend(), plt.grid(), plt.gca().set_ylim(
        0, 1), plt.yticks([c/10 for c in range(11)])

    if not save:
        return plt.show()

    os.makedirs(os.path.dirname(save), exist_ok=True)
    plt.savefig(save, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()


plotModel(trainer.history)

# %% [markdown]
# # DADOS DE TESTE

# %%
test_loss, test_iou = trainer.evaluate(loader=testLoader)
test_iou
# Out:
# 0.6196336150169373

# %%
from torchmetrics.classification import MulticlassJaccardIndex


def getClasses(network, loader, save=None):
    iou_por_classe = MulticlassJaccardIndex(num_classes=network.classes, ignore_index=0, average='none').to(network.device)
    network.model.eval()

    with torch.no_grad():
        for imgs, masks in loader:
            imgs  = imgs.to(network.device)
            masks = masks.to(network.device).squeeze(1) 

            logits = network.model(imgs)
            preds  = torch.argmax(logits, dim=1) 
            iou_por_classe.update(preds, masks)

    ious = iou_por_classe.compute().cpu().numpy()
    ious = {str(i): float(val) for i, val in enumerate(ious)}
    
    ious = dict(sorted(ious.items(), key=lambda item: item[1], reverse=True))
    ious.update({'mean': test_iou})
    
    if '0' in ious:
        del ious['0']

    plt.figure(figsize=(17, 6))
    Plotter(ious)

    if save:
        plt.savefig(save)
        plt.close()  
    
    return ious


if network.multiclass:
    getClasses(network, testLoader)
    plt.show()

# %%
def plotPrediction(index, dataset=testDataset, network=network, alpha=0.5, savePath=None):
    img_tensor, mask_tensor = dataset[index]
    network.model.eval()

    with torch.no_grad():
        img_batch = img_tensor.unsqueeze(0).to(network.device)
        logits = network.model(img_batch)
        pred = torch.argmax(logits, dim=1).squeeze() if network.multiclass else (torch.sigmoid(logits) > 0.5).squeeze().int()

    img_np  = img_tensor.squeeze().cpu().numpy()
    mask_np = mask_tensor.squeeze().cpu().numpy()
    pred_np = pred.cpu().numpy()

    imgNorm = cv2.normalize(img_np, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    imgRgb  = np.stack((imgNorm, imgNorm, imgNorm), axis=-1)
    overlay = imgRgb.copy()
    is_gt   = (mask_np > 0)
    is_pred = (pred_np > 0)
    
    inters = (is_gt & is_pred)   # Acertos / Interseção

    overlay[is_gt]   = [0, 0, 255]  # Azul para o Ground Truth (Falhas reais não detectadas)
    overlay[is_pred] = [255, 0, 0]  # Vermelho para a Predição (Falsos alarmes)
    overlay[inters]  = [0, 255, 0]  # verde onde Predição e GT convergem (Acertos)

    result = (imgRgb * (1 - alpha) + overlay * alpha).astype(np.uint8)
    showTile(img=result, save=savePath)


for i in range(min(len(testDataset), 2)):
    plotPrediction(index=i, dataset=testDataset, network=network)

# %% [markdown]
# # SALVANDO O MODELO

# %%
from datetime import datetime
import json, inspect

# %%
os.makedirs('Backup/', exist_ok=True)
files   = [f for f in os.listdir('Backup/') if f.startswith('model_')]
indexes = sorted([int(path.split('_')[-1]) for path in files]) if len(files) > 0 else [0]
index   = indexes[-1] + 1
folder  = f'Backup/model_{index}'
os.makedirs(folder, exist_ok=True)
folder
# Out:
# 'Backup/model_1'

# %%
iouData = getClasses(network, testLoader, save=os.path.join(folder, 'classes.png')) if network.multiclass else {'mean': test_iou}
path    = os.path.join(folder, 'predictions')
os.makedirs(path, exist_ok=True)

for i in range(min(len(testDataset), 20)):
    plotPrediction(index=i, dataset=testDataset, network=network, savePath=os.path.join(path, f'pred_{i}.png'))

# %%
model_info = {
    'trainer': {
        'path': f'model_{index}',
        'loss': selected_loss,
        'scheduler': scheduler,
        'epochs': trainer.epochs,
        'batch_size': OPTIONS.get('batch_size'),
        'val_iou':  trainer.history[-1].get('val_iou'),
        'test_iou': test_iou
    },

    'processing': OPTIONS,
    'model': model_options,
    'iou': iouData
}

model_data = {
    'model': network.model.state_dict(),
    'optimizer': network.optimizer.state_dict(),
    'timestamp': datetime.now().strftime('%d/%m/%y %H:%M:%S'), 
    'history': trainer.history,
}

with open(f'{folder}/info.json', 'w', encoding='utf-8') as file:
    json.dump(model_info, file, ensure_ascii=False, indent=4)   

plotModel(model_data['history'], save=os.path.join(folder, 'train.png'))
torch.save(model_data, f'{folder}/model.pth')
print('model saved in', folder)
# Out:
# model saved in Backup/model_1
