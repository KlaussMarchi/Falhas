# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import scipy.ndimage as ndimage
import glob, os, shutil, cv2, json, sys
from tqdm import tqdm
from pathlib import Path

# %%
BASE_PATH = '../Dataset/dataset1'

# %%
def getFiles(path, limit=None, shuffle=False):
    target = sorted([os.path.abspath(f) for f in glob.glob(os.path.join(path, '*'))])
    if shuffle:
        np.random.shuffle(target)     
    return target[:limit]

def setFolder(path):
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path)

def getDAT(path):
    return np.fromfile(path, dtype=np.float32).reshape((128, 128, 128))

OPTIONS = json.loads(open('../../Task/info.json', 'r').read())
OPTIONS['dataset'] = BASE_PATH.split('/')[-1].strip()
OPTIONS
# Out:
# {'network': 'resaceunet',
#  'dataset': 'dataset1',
#  'img_size': None,
#  'lr': 0.001,
#  'loss': 'dice_focal',
#  'batch_size': 2,
#  'scheduler': 'plateau',
#  'dropout': 0.1,
#  'num_filters': 16}

# %%
with open('../../Task/info.json', 'w', encoding='utf-8') as file:
    json.dump(OPTIONS, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # CONVERTENDO IMAGENS

# %%
images = getFiles('original/images')
masks  = getFiles('original/masks')

print(images[0])
print(masks[0])
# Out:
# /media/grva-mintcave/BACKUP/marlim_faults/KlaussModel/Falhas/Dataset/dataset1/original/images/0.dat
# /media/grva-mintcave/BACKUP/marlim_faults/KlaussModel/Falhas/Dataset/dataset1/original/masks/0.dat

# %%
def formatAxis(img):
    return np.transpose(img, (0, 2, 1))

def showTile(img, mask=False):
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    
    mid_x = img.shape[0] // 2
    mid_y = img.shape[1] // 2
    mid_z = img.shape[2] // 2

    slices = [
        img[mid_x, :, :],  # Plano YZ (Corte ao longo do eixo X)
        img[:, mid_y, :],  # Plano XZ (Corte ao longo do eixo Y)
        img[:, :, mid_z]   # Plano XY (Corte ao longo do eixo Z)
    ]

    slices[0] = np.array(slices[0])
    arr_y = np.array(slices[1])
    arr_z = np.array(slices[2])
    slices[1] = np.rot90(arr_z, -1)
    slices[2] = arr_y

    cmap_config = ListedColormap(['black', 'red', 'green', 'blue']) if mask else 'gray'
    vmin, vmax  = (0, 3) if mask else (None, None)
    titles = [f'Slice X={mid_x}', f'Slice Y={mid_y}', f'Slice Z={mid_z}']
    
    for i, ax in enumerate(axes):
        ax.imshow(slices[i], cmap=cmap_config, vmin=vmin, vmax=vmax)
        ax.set_title(titles[i])
    
    plt.tight_layout()
    plt.show()

def getImage(base_path, file_name):
    return formatAxis(getDAT(os.path.join(base_path, file_name)))

for i, (img_path, msk_path) in enumerate(zip(images, masks)):
    if i == 2:
        break

    file_name = Path(img_path).name
    print(f'\n\n showing index {i}:', file_name)

    showTile(getImage('original/images', file_name), mask=False)
    showTile(getImage('original/masks',  file_name), mask=True)
# Out:
#  showing index 0: 0.dat
#  showing index 1: 1.dat

# %% [markdown]
# ### Opcional - Normalização com Percentil

# %%
arrays = [getDAT(path) for path in images]
p01 = np.percentile(arrays, 1)
p99 = np.percentile(arrays, 99)
del arrays

def normalize(img):
    clipped = np.clip(img, p01, p99)   
    return (clipped - p01) / (p99 - p01)

# %%
setFolder('images')
setFolder('masks')

for img_path, msk_path in tqdm(zip(images, masks), total=len(images)):
    img = getImage('original/images', Path(img_path).name)
    msk = getImage('original/masks',  Path(msk_path).name)

    img = normalize(img)
    file_name = Path(img_path).stem
    
    np.save(os.path.join('images', f'{file_name}.npy'), img)
    np.save(os.path.join('masks',  f'{file_name}.npy'),  msk)
# Out:
# 100%|██████████| 220/220 [02:38<00:00,  1.39it/s]

# %%
df = pd.DataFrame()
df['img_path']  = [file for file in getFiles('images')]
df['mask_path'] = [file for file in getFiles('masks')]
df['shape']     = [np.load(path).shape for path in df.img_path]
df['min']  = [np.min(np.load(path))  for path in df.img_path]
df['max']  = [np.max(np.load(path))  for path in df.img_path]
df['mean'] = [np.mean(np.load(path)) for path in df.img_path]
df['std']  = [np.std(np.load(path))  for path in df.img_path]

print(df.img_path.iloc[2])
df
# Out:
# /media/grva-mintcave/BACKUP/marlim_faults/KlaussModel/Falhas/Dataset/dataset1/images/10.npy
#                                               img_path  \
# 0    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 1    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 2    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 3    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 4    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# ..                                                 ...
# 215  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 216  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 217  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 218  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 219  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
#
#                                              mask_path            shape  min  \
# 0    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 1    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 2    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 3    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 4    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# ..                                                 ...              ...  ...
# 215  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 216  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 217  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 218  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 219  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
#
#      max      mean       std
# 0    1.0  0.497236  0.211666
# 1    1.0  0.496481  0.184599
# 2    1.0  0.496158  0.185499
# 3    1.0  0.496550  0.203066
# 4    1.0  0.497008  0.210493
# ..   ...       ...       ...
# 215  1.0  0.495437  0.192614
# 216  1.0  0.495381  0.201204
# 217  1.0  0.495210  0.186244
# 218  1.0  0.494706  0.201227
# 219  1.0  0.494051  0.210159
#
# [220 rows x 7 columns]

# %%
if OPTIONS.get('img_size') is None:
    df.to_csv('../DataBase.csv', index=None)
    display(df)
    sys.exit("Finalizando o programa: sem tiles nessa rodada")
# Out:
#                                               img_path  \
# 0    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 1    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 2    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 3    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 4    /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# ..                                                 ...
# 215  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 216  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 217  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 218  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
# 219  /media/grva-mintcave/BACKUP/marlim_faults/Klau...
#
#                                              mask_path            shape  min  \
# 0    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 1    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 2    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 3    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 4    /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# ..                                                 ...              ...  ...
# 215  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 216  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 217  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 218  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
# 219  /media/grva-mintcave/BACKUP/marlim_faults/Klau...  (128, 128, 128)  0.0
#
#      max      mean       std
# 0    1.0  0.497236  0.211666
# 1    1.0  0.496481  0.184599
# 2    1.0  0.496158  0.185499
# 3    1.0  0.496550  0.203066
# 4    1.0  0.497008  0.210493
# ..   ...       ...       ...
# 215  1.0  0.495437  0.192614
# 216  1.0  0.495381  0.201204
# 217  1.0  0.495210  0.186244
# 218  1.0  0.494706  0.201227
# 219  1.0  0.494051  0.210159
#
# [220 rows x 7 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Finalizando o programa: sem tiles nessa rodada
# /home/grva-mintcave/miniconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # TILES

# %%
IMG_SIZE = tuple(OPTIONS['img_size'])
IMG_SIZE
# Out:
# (4, 128, 128)

# %%
class TilesBuilder:
    def __init__(self, target_size=(8, 64, 128), main_dir='tiles'):
        self.target_size = target_size
        self.main_dir    = main_dir

        if os.path.exists(main_dir):
            shutil.rmtree(main_dir)
        os.makedirs(main_dir)

    def update(self, file_path, target_dir, is_mask=False):
        folder = os.path.join(self.main_dir, target_dir)
        os.makedirs(folder, exist_ok=True)

        data = getDAT(file_path)
        base_name     = os.path.splitext(os.path.basename(file_path))[0]
        z_t, y_t, x_t = self.target_size
        
        z_pad = (z_t - data.shape[0] % z_t) % z_t
        y_pad = (y_t - data.shape[1] % y_t) % y_t
        x_pad = (x_t - data.shape[2] % x_t) % x_t

        pad_mode    = 'constant' if is_mask else 'reflect'
        data_padded = np.pad(data, ((0, z_pad), (0, y_pad), (0, x_pad)), mode=pad_mode) if z_pad > 0 or y_pad > 0 or x_pad > 0 else data
            
        index = 0
        for z in range(0, data_padded.shape[0], z_t):
            for y in range(0, data_padded.shape[1], y_t):
                for x in range(0, data_padded.shape[2], x_t):
                    tile = data_padded[z:z+z_t, y:y+y_t, x:x+x_t]
                    save_path = os.path.join(folder, f'{base_name}_tile_{index}.npy')
                    
                    np.save(save_path, tile)
                    index = (index + 1)


tiles = TilesBuilder(target_size=IMG_SIZE, main_dir='tiles')
for img_path, mask_path in tqdm(zip(images, masks), total=len(df)):
    tiles.update(img_path,  'images/', is_mask=False)
    tiles.update(mask_path, 'masks/',  is_mask=True)
# Out:
# 100%|██████████| 220/220 [00:02<00:00, 89.92it/s]

# %%
print(len(getFiles('tiles/images')), 'imagens geradas')
# Out:
# 7040 imagens geradas

# %%
df = pd.DataFrame()
df['img_path'] = [file for file in getFiles('tiles/images')]
df['mask_path'] = [file for file in getFiles('tiles/masks')]
df['shape']    = [(128, 128, 128) for path in df.img_path]
df['min']  = [np.min(getDAT(path))  for path in df.img_path]
df['max']  = [np.max(getDAT(path))  for path in df.img_path]
df['mean'] = [np.mean(getDAT(path)) for path in df.img_path]
df['std']  = [np.std(getDAT(path))  for path in df.img_path]

print(df.img_path.iloc[2])
df.to_csv('../DataBase.csv', index=None)
df
# Out:
#                                             img_path  \
# 0      ../Dataset/dataset0/tiles/images/0_tile_0.npy
# 1      ../Dataset/dataset0/tiles/images/0_tile_1.npy
# 2     ../Dataset/dataset0/tiles/images/0_tile_10.npy
# 3     ../Dataset/dataset0/tiles/images/0_tile_11.npy
# 4     ../Dataset/dataset0/tiles/images/0_tile_12.npy
# ...                                              ...
# 7035   ../Dataset/dataset0/tiles/images/9_tile_5.npy
# 7036   ../Dataset/dataset0/tiles/images/9_tile_6.npy
# 7037   ../Dataset/dataset0/tiles/images/9_tile_7.npy
# 7038   ../Dataset/dataset0/tiles/images/9_tile_8.npy
# 7039   ../Dataset/dataset0/tiles/images/9_tile_9.npy
#
#                                           mask_path          shape
# 0      ../Dataset/dataset0/tiles/masks/0_tile_0.npy  (4, 128, 128)
# 1      ../Dataset/dataset0/tiles/masks/0_tile_1.npy  (4, 128, 128)
# 2     ../Dataset/dataset0/tiles/masks/0_tile_10.npy  (4, 128, 128)
# 3     ../Dataset/dataset0/tiles/masks/0_tile_11.npy  (4, 128, 128)
# 4     ../Dataset/dataset0/tiles/masks/0_tile_12.npy  (4, 128, 128)
# ...                                             ...            ...
# 7035   ../Dataset/dataset0/tiles/masks/9_tile_5.npy  (4, 128, 128)
# 7036   ../Dataset/dataset0/tiles/masks/9_tile_6.npy  (4, 128, 128)
# 7037   ../Dataset/dataset0/tiles/masks/9_tile_7.npy  (4, 128, 128)
# 7038   ../Dataset/dataset0/tiles/masks/9_tile_8.npy  (4, 128, 128)
# 7039   ../Dataset/dataset0/tiles/masks/9_tile_9.npy  (4, 128, 128)
#
# [7040 rows x 3 columns]
