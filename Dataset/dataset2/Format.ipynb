# %%
from matplotlib.colors import ListedColormap
import glob, os, shutil, cv2, json, sys
import scipy.ndimage as ndimage
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
BASE_PATH = '../Dataset/dataset2'

# %%
def getFiles(path, limit=None, shuffle=False):
    target = sorted(glob.glob(os.path.join(path, '*')))
    if shuffle:
        np.random.shuffle(target) 
    return target[:limit]

def setFolder(path):
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path)


OPTIONS = json.loads(open('../../Task/info.json', 'r').read())
OPTIONS['dataset'] = BASE_PATH.split('/')[-1].strip()
OPTIONS
# Out:
# {'network': 'segresnet',
#  'img_size': None,
#  'lr': 0.0005,
#  'loss': 'dice',
#  'batch_size': 4,
#  'scheduler': 'plateau',
#  'dropout': 0.1,
#  'num_filters': 32,
#  'dataset': 'dataset2'}

# %%
with open('../../Task/info.json', 'w', encoding='utf-8') as file:
    json.dump(OPTIONS, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # CONVERTENDO IMAGENS

# %%
os.listdir()
# Out:
# ['masks', 'Format.ipynb', 'original', 'images']

# %%
images = sorted(os.listdir('original/images'))
masks  = sorted(os.listdir('original/masks'))

print(images[0])
print(masks[0])
# Out:
# img_0000.npy
# img_0000.npy

# %%
def formatAxis(img):
    return np.transpose(img, (0, 1, 2))

def showTile(img, mask=False):
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    
    mid_x = img.shape[0] // 2
    mid_y = img.shape[1] // 2
    mid_z = img.shape[2] // 2

    slices = [
        img[mid_x, :, :],  # Plano YZ (Corte ao longo do eixo X)
        img[:, mid_y, :],  # Plano XZ (Corte ao longo do eixo Y)
        img[:, :, mid_z]   # Plano XY (Corte ao longo do eixo Z)
    ]

    slices[0] = np.array(slices[0])
    arr_y = np.array(slices[1])
    arr_z = np.array(slices[2])
    slices[1] = np.rot90(arr_z, -1)
    slices[2] = arr_y

    cmap_config = ListedColormap(['black', 'red', 'green', 'blue']) if mask else 'gray'
    vmin, vmax  = (0, 3) if mask else (None, None)
    titles = [f'Slice X={mid_x}', f'Slice Y={mid_y}', f'Slice Z={mid_z}']
    
    for i, ax in enumerate(axes):
        ax.imshow(slices[i], cmap=cmap_config, vmin=vmin, vmax=vmax)
        ax.set_title(titles[i])
    
    plt.tight_layout()
    plt.show()

def getImage(base_path, file_name):
    return formatAxis(np.load(os.path.join(base_path, file_name)))

for i, (img_path, msk_path) in enumerate(zip(images, masks)):
    if i == 5:
        break

    img = getImage('original/images', img_path)
    print(np.min(img), np.max(img), np.mean(img), np.std(img))
    
    print(f'\n\n showing index {i}')
    showTile(getImage('original/images', img_path), mask=False)
    showTile(getImage('original/masks',  msk_path), mask=True)
# Out:
# -4.3697104 4.688896 -2.5465852e-10 1.0000001
#
#
#  showing index 0
# -4.088923 4.4161396 -2.2100721e-10 0.99999994
#
#
#  showing index 1
# -4.5585318 4.344842 -6.91216e-11 1.0
#
#
#  showing index 2
# -4.0987735 4.1533785 7.275958e-12 1.0000002
#
#
#  showing index 3
# -3.7583647 3.439421 -1.1277734e-10 0.9999998
#
#
#  showing index 4

# %%
setFolder('images')
setFolder('masks')

for img_path, msk_path in tqdm(zip(images, masks), total=len(images)):
    np.save(os.path.join('images', img_path), getImage('original/images', img_path))
    np.save(os.path.join('masks', msk_path),  getImage('original/masks',  msk_path))

images = getFiles('images')
masks  = getFiles('masks')

print(images[0])
print(masks[0])
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 193.81it/s]
# images/img_0000.npy
# masks/img_0000.npy

# %%
df = pd.DataFrame()
df['img_path']  = [os.path.join(BASE_PATH, path) for path in images]
df['mask_path'] = [os.path.join(BASE_PATH, path) for path in masks]
df['shape'] = [np.load(path).shape for path in getFiles('images')]
df
# Out:
#                                    img_path  \
# 0   ../Dataset/dataset2/images/img_0000.npy
# 1   ../Dataset/dataset2/images/img_0001.npy
# 2   ../Dataset/dataset2/images/img_0002.npy
# 3   ../Dataset/dataset2/images/img_0003.npy
# 4   ../Dataset/dataset2/images/img_0004.npy
# 5   ../Dataset/dataset2/images/img_0005.npy
# 6   ../Dataset/dataset2/images/img_0006.npy
# 7   ../Dataset/dataset2/images/img_0007.npy
# 8   ../Dataset/dataset2/images/img_0008.npy
# 9   ../Dataset/dataset2/images/img_0009.npy
# 10  ../Dataset/dataset2/images/img_0010.npy
# 11  ../Dataset/dataset2/images/img_0011.npy
# 12  ../Dataset/dataset2/images/img_0012.npy
# 13  ../Dataset/dataset2/images/img_0013.npy
# 14  ../Dataset/dataset2/images/img_0014.npy
# 15  ../Dataset/dataset2/images/img_0015.npy
# 16  ../Dataset/dataset2/images/img_0016.npy
# 17  ../Dataset/dataset2/images/img_0017.npy
# 18  ../Dataset/dataset2/images/img_0018.npy
# 19  ../Dataset/dataset2/images/img_0019.npy
# 20  ../Dataset/dataset2/images/img_0020.npy
# 21  ../Dataset/dataset2/images/img_0021.npy
# 22  ../Dataset/dataset2/images/img_0022.npy
# 23  ../Dataset/dataset2/images/img_0023.npy
# 24  ../Dataset/dataset2/images/img_0024.npy
# 25  ../Dataset/dataset2/images/img_0025.npy
# 26  ../Dataset/dataset2/images/img_0026.npy
# 27  ../Dataset/dataset2/images/img_0027.npy
# 28  ../Dataset/dataset2/images/img_0028.npy
# 29  ../Dataset/dataset2/images/img_0029.npy
# 30  ../Dataset/dataset2/images/img_0030.npy
# 31  ../Dataset/dataset2/images/img_0031.npy
# 32  ../Dataset/dataset2/images/img_0032.npy
# 33  ../Dataset/dataset2/images/img_0033.npy
# 34  ../Dataset/dataset2/images/img_0034.npy
# 35  ../Dataset/dataset2/images/img_0035.npy
# 36  ../Dataset/dataset2/images/img_0036.npy
# 37  ../Dataset/dataset2/images/img_0037.npy
# 38  ../Dataset/dataset2/images/img_0038.npy
# 39  ../Dataset/dataset2/images/img_0039.npy
# 40  ../Dataset/dataset2/images/img_0040.npy
# 41  ../Dataset/dataset2/images/img_0041.npy
# 42  ../Dataset/dataset2/images/img_0042.npy
# 43  ../Dataset/dataset2/images/img_0043.npy
# 44  ../Dataset/dataset2/images/img_0044.npy
# 45  ../Dataset/dataset2/images/img_0045.npy
# 46  ../Dataset/dataset2/images/img_0046.npy
# 47  ../Dataset/dataset2/images/img_0047.npy
# 48  ../Dataset/dataset2/images/img_0048.npy
# 49  ../Dataset/dataset2/images/img_0049.npy
#
#                                  mask_path            shape
# 0   ../Dataset/dataset2/masks/img_0000.npy  (128, 128, 128)
# 1   ../Dataset/dataset2/masks/img_0001.npy  (128, 128, 128)
# 2   ../Dataset/dataset2/masks/img_0002.npy  (128, 128, 128)
# 3   ../Dataset/dataset2/masks/img_0003.npy  (128, 128, 128)
# 4   ../Dataset/dataset2/masks/img_0004.npy  (128, 128, 128)
# 5   ../Dataset/dataset2/masks/img_0005.npy  (128, 128, 128)
# 6   ../Dataset/dataset2/masks/img_0006.npy  (128, 128, 128)
# 7   ../Dataset/dataset2/masks/img_0007.npy  (128, 128, 128)
# 8   ../Dataset/dataset2/masks/img_0008.npy  (128, 128, 128)
# 9   ../Dataset/dataset2/masks/img_0009.npy  (128, 128, 128)
# 10  ../Dataset/dataset2/masks/img_0010.npy  (128, 128, 128)
# 11  ../Dataset/dataset2/masks/img_0011.npy  (128, 128, 128)
# 12  ../Dataset/dataset2/masks/img_0012.npy  (128, 128, 128)
# 13  ../Dataset/dataset2/masks/img_0013.npy  (128, 128, 128)
# 14  ../Dataset/dataset2/masks/img_0014.npy  (128, 128, 128)
# 15  ../Dataset/dataset2/masks/img_0015.npy  (128, 128, 128)
# 16  ../Dataset/dataset2/masks/img_0016.npy  (128, 128, 128)
# 17  ../Dataset/dataset2/masks/img_0017.npy  (128, 128, 128)
# 18  ../Dataset/dataset2/masks/img_0018.npy  (128, 128, 128)
# 19  ../Dataset/dataset2/masks/img_0019.npy  (128, 128, 128)
# 20  ../Dataset/dataset2/masks/img_0020.npy  (128, 128, 128)
# 21  ../Dataset/dataset2/masks/img_0021.npy  (128, 128, 128)
# 22  ../Dataset/dataset2/masks/img_0022.npy  (128, 128, 128)
# 23  ../Dataset/dataset2/masks/img_0023.npy  (128, 128, 128)
# 24  ../Dataset/dataset2/masks/img_0024.npy  (128, 128, 128)
# 25  ../Dataset/dataset2/masks/img_0025.npy  (128, 128, 128)
# 26  ../Dataset/dataset2/masks/img_0026.npy  (128, 128, 128)
# 27  ../Dataset/dataset2/masks/img_0027.npy  (128, 128, 128)
# 28  ../Dataset/dataset2/masks/img_0028.npy  (128, 128, 128)
# 29  ../Dataset/dataset2/masks/img_0029.npy  (128, 128, 128)
# 30  ../Dataset/dataset2/masks/img_0030.npy  (128, 128, 128)
# 31  ../Dataset/dataset2/masks/img_0031.npy  (128, 128, 128)
# 32  ../Dataset/dataset2/masks/img_0032.npy  (128, 128, 128)
# 33  ../Dataset/dataset2/masks/img_0033.npy  (128, 128, 128)
# 34  ../Dataset/dataset2/masks/img_0034.npy  (128, 128, 128)
# 35  ../Dataset/dataset2/masks/img_0035.npy  (128, 128, 128)
# 36  ../Dataset/dataset2/masks/img_0036.npy  (128, 128, 128)
# 37  ../Dataset/dataset2/masks/img_0037.npy  (128, 128, 128)
# 38  ../Dataset/dataset2/masks/img_0038.npy  (128, 128, 128)
# 39  ../Dataset/dataset2/masks/img_0039.npy  (128, 128, 128)
# 40  ../Dataset/dataset2/masks/img_0040.npy  (128, 128, 128)
# 41  ../Dataset/dataset2/masks/img_0041.npy  (128, 128, 128)
# 42  ../Dataset/dataset2/masks/img_0042.npy  (128, 128, 128)
# 43  ../Dataset/dataset2/masks/img_0043.npy  (128, 128, 128)
# 44  ../Dataset/dataset2/masks/img_0044.npy  (128, 128, 128)
# 45  ../Dataset/dataset2/masks/img_0045.npy  (128, 128, 128)
# 46  ../Dataset/dataset2/masks/img_0046.npy  (128, 128, 128)
# 47  ../Dataset/dataset2/masks/img_0047.npy  (128, 128, 128)
# 48  ../Dataset/dataset2/masks/img_0048.npy  (128, 128, 128)
# 49  ../Dataset/dataset2/masks/img_0049.npy  (128, 128, 128)

# %%
if OPTIONS.get('img_size') is None:
    df.to_csv('../DataBase.csv', index=None)
    display(df)
    sys.exit("Finalizando o programa: sem tiles nessa rodada")
# Out:
#                                    img_path  \
# 0   ../Dataset/dataset2/images/img_0000.npy
# 1   ../Dataset/dataset2/images/img_0001.npy
# 2   ../Dataset/dataset2/images/img_0002.npy
# 3   ../Dataset/dataset2/images/img_0003.npy
# 4   ../Dataset/dataset2/images/img_0004.npy
# 5   ../Dataset/dataset2/images/img_0005.npy
# 6   ../Dataset/dataset2/images/img_0006.npy
# 7   ../Dataset/dataset2/images/img_0007.npy
# 8   ../Dataset/dataset2/images/img_0008.npy
# 9   ../Dataset/dataset2/images/img_0009.npy
# 10  ../Dataset/dataset2/images/img_0010.npy
# 11  ../Dataset/dataset2/images/img_0011.npy
# 12  ../Dataset/dataset2/images/img_0012.npy
# 13  ../Dataset/dataset2/images/img_0013.npy
# 14  ../Dataset/dataset2/images/img_0014.npy
# 15  ../Dataset/dataset2/images/img_0015.npy
# 16  ../Dataset/dataset2/images/img_0016.npy
# 17  ../Dataset/dataset2/images/img_0017.npy
# 18  ../Dataset/dataset2/images/img_0018.npy
# 19  ../Dataset/dataset2/images/img_0019.npy
# 20  ../Dataset/dataset2/images/img_0020.npy
# 21  ../Dataset/dataset2/images/img_0021.npy
# 22  ../Dataset/dataset2/images/img_0022.npy
# 23  ../Dataset/dataset2/images/img_0023.npy
# 24  ../Dataset/dataset2/images/img_0024.npy
# 25  ../Dataset/dataset2/images/img_0025.npy
# 26  ../Dataset/dataset2/images/img_0026.npy
# 27  ../Dataset/dataset2/images/img_0027.npy
# 28  ../Dataset/dataset2/images/img_0028.npy
# 29  ../Dataset/dataset2/images/img_0029.npy
# 30  ../Dataset/dataset2/images/img_0030.npy
# 31  ../Dataset/dataset2/images/img_0031.npy
# 32  ../Dataset/dataset2/images/img_0032.npy
# 33  ../Dataset/dataset2/images/img_0033.npy
# 34  ../Dataset/dataset2/images/img_0034.npy
# 35  ../Dataset/dataset2/images/img_0035.npy
# 36  ../Dataset/dataset2/images/img_0036.npy
# 37  ../Dataset/dataset2/images/img_0037.npy
# 38  ../Dataset/dataset2/images/img_0038.npy
# 39  ../Dataset/dataset2/images/img_0039.npy
# 40  ../Dataset/dataset2/images/img_0040.npy
# 41  ../Dataset/dataset2/images/img_0041.npy
# 42  ../Dataset/dataset2/images/img_0042.npy
# 43  ../Dataset/dataset2/images/img_0043.npy
# 44  ../Dataset/dataset2/images/img_0044.npy
# 45  ../Dataset/dataset2/images/img_0045.npy
# 46  ../Dataset/dataset2/images/img_0046.npy
# 47  ../Dataset/dataset2/images/img_0047.npy
# 48  ../Dataset/dataset2/images/img_0048.npy
# 49  ../Dataset/dataset2/images/img_0049.npy
#
#                                  mask_path            shape
# 0   ../Dataset/dataset2/masks/img_0000.npy  (128, 128, 128)
# 1   ../Dataset/dataset2/masks/img_0001.npy  (128, 128, 128)
# 2   ../Dataset/dataset2/masks/img_0002.npy  (128, 128, 128)
# 3   ../Dataset/dataset2/masks/img_0003.npy  (128, 128, 128)
# 4   ../Dataset/dataset2/masks/img_0004.npy  (128, 128, 128)
# 5   ../Dataset/dataset2/masks/img_0005.npy  (128, 128, 128)
# 6   ../Dataset/dataset2/masks/img_0006.npy  (128, 128, 128)
# 7   ../Dataset/dataset2/masks/img_0007.npy  (128, 128, 128)
# 8   ../Dataset/dataset2/masks/img_0008.npy  (128, 128, 128)
# 9   ../Dataset/dataset2/masks/img_0009.npy  (128, 128, 128)
# 10  ../Dataset/dataset2/masks/img_0010.npy  (128, 128, 128)
# 11  ../Dataset/dataset2/masks/img_0011.npy  (128, 128, 128)
# 12  ../Dataset/dataset2/masks/img_0012.npy  (128, 128, 128)
# 13  ../Dataset/dataset2/masks/img_0013.npy  (128, 128, 128)
# 14  ../Dataset/dataset2/masks/img_0014.npy  (128, 128, 128)
# 15  ../Dataset/dataset2/masks/img_0015.npy  (128, 128, 128)
# 16  ../Dataset/dataset2/masks/img_0016.npy  (128, 128, 128)
# 17  ../Dataset/dataset2/masks/img_0017.npy  (128, 128, 128)
# 18  ../Dataset/dataset2/masks/img_0018.npy  (128, 128, 128)
# 19  ../Dataset/dataset2/masks/img_0019.npy  (128, 128, 128)
# 20  ../Dataset/dataset2/masks/img_0020.npy  (128, 128, 128)
# 21  ../Dataset/dataset2/masks/img_0021.npy  (128, 128, 128)
# 22  ../Dataset/dataset2/masks/img_0022.npy  (128, 128, 128)
# 23  ../Dataset/dataset2/masks/img_0023.npy  (128, 128, 128)
# 24  ../Dataset/dataset2/masks/img_0024.npy  (128, 128, 128)
# 25  ../Dataset/dataset2/masks/img_0025.npy  (128, 128, 128)
# 26  ../Dataset/dataset2/masks/img_0026.npy  (128, 128, 128)
# 27  ../Dataset/dataset2/masks/img_0027.npy  (128, 128, 128)
# 28  ../Dataset/dataset2/masks/img_0028.npy  (128, 128, 128)
# 29  ../Dataset/dataset2/masks/img_0029.npy  (128, 128, 128)
# 30  ../Dataset/dataset2/masks/img_0030.npy  (128, 128, 128)
# 31  ../Dataset/dataset2/masks/img_0031.npy  (128, 128, 128)
# 32  ../Dataset/dataset2/masks/img_0032.npy  (128, 128, 128)
# 33  ../Dataset/dataset2/masks/img_0033.npy  (128, 128, 128)
# 34  ../Dataset/dataset2/masks/img_0034.npy  (128, 128, 128)
# 35  ../Dataset/dataset2/masks/img_0035.npy  (128, 128, 128)
# 36  ../Dataset/dataset2/masks/img_0036.npy  (128, 128, 128)
# 37  ../Dataset/dataset2/masks/img_0037.npy  (128, 128, 128)
# 38  ../Dataset/dataset2/masks/img_0038.npy  (128, 128, 128)
# 39  ../Dataset/dataset2/masks/img_0039.npy  (128, 128, 128)
# 40  ../Dataset/dataset2/masks/img_0040.npy  (128, 128, 128)
# 41  ../Dataset/dataset2/masks/img_0041.npy  (128, 128, 128)
# 42  ../Dataset/dataset2/masks/img_0042.npy  (128, 128, 128)
# 43  ../Dataset/dataset2/masks/img_0043.npy  (128, 128, 128)
# 44  ../Dataset/dataset2/masks/img_0044.npy  (128, 128, 128)
# 45  ../Dataset/dataset2/masks/img_0045.npy  (128, 128, 128)
# 46  ../Dataset/dataset2/masks/img_0046.npy  (128, 128, 128)
# 47  ../Dataset/dataset2/masks/img_0047.npy  (128, 128, 128)
# 48  ../Dataset/dataset2/masks/img_0048.npy  (128, 128, 128)
# 49  ../Dataset/dataset2/masks/img_0049.npy  (128, 128, 128)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Finalizando o programa: sem tiles nessa rodada
# /home/grva-mint/anaconda3/envs/torch-gpu/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # TILES

# %%
IMG_SIZE = tuple(OPTIONS['img_size'])
IMG_SIZE
# Out:
# (4, 128, 128)

# %%
class TilesBuilder:
    def __init__(self, target_size=(8, 64, 128), main_dir='tiles'):
        self.target_size = target_size
        self.main_dir    = main_dir

        if os.path.exists(main_dir):
            shutil.rmtree(main_dir)
        os.makedirs(main_dir)

    def update(self, file_path, target_dir, is_mask=False):
        folder = os.path.join(self.main_dir, target_dir)
        os.makedirs(folder, exist_ok=True)
        data = np.load(file_path)

        base_name     = os.path.splitext(os.path.basename(file_path))[0]
        z_t, y_t, x_t = self.target_size
        
        z_pad = (z_t - data.shape[0] % z_t) % z_t
        y_pad = (y_t - data.shape[1] % y_t) % y_t
        x_pad = (x_t - data.shape[2] % x_t) % x_t

        pad_mode    = 'constant' if is_mask else 'reflect'
        data_padded = np.pad(data, ((0, z_pad), (0, y_pad), (0, x_pad)), mode=pad_mode) if z_pad > 0 or y_pad > 0 or x_pad > 0 else data
            
        index = 0
        for z in range(0, data_padded.shape[0], z_t):
            for y in range(0, data_padded.shape[1], y_t):
                for x in range(0, data_padded.shape[2], x_t):
                    tile = data_padded[z:z+z_t, y:y+y_t, x:x+x_t]
                    save_path = os.path.join(folder, f'{base_name}_tile_{index}.npy')
                    
                    np.save(save_path, tile)
                    index = (index + 1)


tiles = TilesBuilder(target_size=IMG_SIZE, main_dir='tiles')
for img_path, mask_path in tqdm(zip(images, masks), total=len(df)):
    tiles.update(img_path,  'images/', is_mask=False)
    tiles.update(mask_path, 'masks/',  is_mask=True)
# Out:
# 100%|██████████| 200/200 [00:01<00:00, 143.40it/s]

# %%
print(len(getFiles('tiles/images')), 'imagens geradas')
# Out:
# 6400 imagens geradas

# %%
df = pd.DataFrame()
df['img_path']  = [os.path.join(BASE_PATH, path) for path in getFiles('tiles/images')]
df['mask_path'] = [os.path.join(BASE_PATH, path) for path in getFiles('tiles/masks')]
df['shape'] = [tiles.target_size for _ in range(len(df))]

df.to_csv('../DataBase.csv', index=None)
df
# Out:
#                                                img_path  \
# 0     ../Dataset/dataset1/tiles/images/img_0000_tile...
# 1     ../Dataset/dataset1/tiles/images/img_0000_tile...
# 2     ../Dataset/dataset1/tiles/images/img_0000_tile...
# 3     ../Dataset/dataset1/tiles/images/img_0000_tile...
# 4     ../Dataset/dataset1/tiles/images/img_0000_tile...
# ...                                                 ...
# 6395  ../Dataset/dataset1/tiles/images/img_0199_tile...
# 6396  ../Dataset/dataset1/tiles/images/img_0199_tile...
# 6397  ../Dataset/dataset1/tiles/images/img_0199_tile...
# 6398  ../Dataset/dataset1/tiles/images/img_0199_tile...
# 6399  ../Dataset/dataset1/tiles/images/img_0199_tile...
#
#                                               mask_path          shape
# 0     ../Dataset/dataset1/tiles/masks/img_0000_tile_...  (4, 128, 128)
# 1     ../Dataset/dataset1/tiles/masks/img_0000_tile_...  (4, 128, 128)
# 2     ../Dataset/dataset1/tiles/masks/img_0000_tile_...  (4, 128, 128)
# 3     ../Dataset/dataset1/tiles/masks/img_0000_tile_...  (4, 128, 128)
# 4     ../Dataset/dataset1/tiles/masks/img_0000_tile_...  (4, 128, 128)
# ...                                                 ...            ...
# 6395  ../Dataset/dataset1/tiles/masks/img_0199_tile_...  (4, 128, 128)
# 6396  ../Dataset/dataset1/tiles/masks/img_0199_tile_...  (4, 128, 128)
# 6397  ../Dataset/dataset1/tiles/masks/img_0199_tile_...  (4, 128, 128)
# 6398  ../Dataset/dataset1/tiles/masks/img_0199_tile_...  (4, 128, 128)
# 6399  ../Dataset/dataset1/tiles/masks/img_0199_tile_...  (4, 128, 128)
#
# [6400 rows x 3 columns]
