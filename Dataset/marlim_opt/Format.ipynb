# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import scipy.ndimage as ndimage
import glob, os, shutil, cv2, json, sys
from tqdm import tqdm
from pathlib import Path

# %%
BASE_PATH = f'../Dataset/{Path().resolve().name}'
BASE_PATH
# Out:
# '../Dataset/marlim_opt'

# %%
def getFiles(path, limit=None, shuffle=False):
    target = sorted([os.path.abspath(f) for f in glob.glob(os.path.join(path, '*'))])
    if shuffle:
        np.random.shuffle(target)     
    return target[:limit]

def setFolder(path):
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path)

def getDAT(path):
    return np.fromfile(path, dtype=np.float32).reshape((128, 128, 128))

OPTIONS = json.loads(open('../../Task/info.json', 'r').read())
OPTIONS['dataset'] = BASE_PATH.split('/')[-1].strip()
OPTIONS
# Out:
# {'network': 'unet3d_v2',
#  'dataset': 'marlim_opt',
#  'img_size': None,
#  'lr': 0.001,
#  'loss': 'dice_focal',
#  'batch_size': 2,
#  'scheduler': 'plateau',
#  'dropout': 0.1,
#  'num_filters': 32}

# %%
with open('../../Task/info.json', 'w', encoding='utf-8') as file:
    json.dump(OPTIONS, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # CONVERTENDO IMAGENS

# %%
images = getFiles('original/images')
masks  = getFiles('original/masks')

print(images[0])
print(masks[0])
# Out:
# /home/grva-mint/Projects/Falhas/Dataset/marlim_opt/original/images/img_0000.npy
# /home/grva-mint/Projects/Falhas/Dataset/marlim_opt/original/masks/img_0000.npy

# %%
def formatAxis(img):
    return img # np.transpose(img, (0, 2, 1))

def getImage(base_path, file_name=None):
    path = os.path.join(base_path, file_name) if file_name else base_path
    return formatAxis(np.load(path))

def showTile(img=None, mask=None, save=None):
    if img is None and mask is None:
        return print("Erro: Forneça pelo menos 'img' ou 'mask'.")

    ref_vol = img if img is not None else mask
    mid_x = ref_vol.shape[0] // 2
    mid_y = ref_vol.shape[1] // 2
    mid_z = ref_vol.shape[2] // 2

    def get_slices(vol):
        if vol is None:
            return None
        
        s_x = np.array(vol[mid_x, :, :]) # Plano YZ
        s_y = np.array(vol[:, mid_y, :]) # Plano XZ
        s_z = np.array(vol[:, :, mid_z]) # Plano XY
        return [s_x, np.rot90(s_z, -1), s_y]

    img_slices  = get_slices(img)
    mask_slices = get_slices(mask)
    cmap_mask_only    = ListedColormap(['black', 'red', 'green', 'blue'])
    cmap_mask_overlay = ListedColormap([(0, 0, 0, 0), 'red', 'green', 'blue'])

    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    titles    = [f'Slice X={mid_x}', f'Slice Y={mid_y}', f'Slice Z={mid_z}']

    for i, ax in enumerate(axes):
        if img is not None:
            ax.imshow(img_slices[i], cmap='gray')
            
        if mask is not None:
            if img is not None:
                ax.imshow(mask_slices[i], cmap=cmap_mask_overlay, vmin=0, vmax=3, alpha=0.6)
            else:
                ax.imshow(mask_slices[i], cmap=cmap_mask_only, vmin=0, vmax=3)
        
        ax.set_title(titles[i])

    plt.tight_layout()

    if save:
        plt.savefig(save, bbox_inches='tight', dpi=300)
        return plt.close(fig)

    plt.show()

for i, (img_path, msk_path) in enumerate(zip(images, masks)):
    if i == 6:
        break

    file_name = Path(img_path).name
    print(f'\n\n showing index {i}:', file_name)

    img  = getImage('original/images', file_name)
    mask = getImage('original/masks',  file_name)

    print(img.min(), img.max())
    showTile(img=img)
    showTile(img=img, mask=mask)
# Out:
#  showing index 0: img_0000.npy
# -0.45 0.32985088
#  showing index 1: img_0001.npy
# -0.45 0.30719918
#  showing index 2: img_0002.npy
# -0.45 0.45
#  showing index 3: img_0003.npy
# -0.09687587 0.08873689
#  showing index 4: img_0004.npy
# -0.12254051 0.1115385
#  showing index 5: img_0005.npy
# -0.45 0.45

# %% [markdown]
# ### Opcional - Normalização com Percentil

# %%
arrays = [np.load(path) for path in images]
p01 = np.percentile(arrays, 1)
p99 = np.percentile(arrays, 99)
print(p01, p99); del arrays

def normalize(img):
    clipped = np.clip(img, p01, p99)   
    return (clipped - p01) / (p99 - p01)

setFolder('images')
setFolder('masks')

for img_path, msk_path in tqdm(zip(images, masks), total=len(images)):
    img = getImage('original/images', Path(img_path).name)
    msk = getImage('original/masks',  Path(msk_path).name)

    img = normalize(img)
    file_name = Path(img_path).stem
    
    np.save(os.path.join('images', f'{file_name}.npy'), img)
    np.save(os.path.join('masks',  f'{file_name}.npy'), msk)
# Out:
# -0.45 0.45
# 100%|██████████| 220/220 [00:02<00:00, 100.92it/s]

# %%
df = [] 

for img_path, mask_path in tqdm(zip(getFiles('images'), getFiles('masks'))):
    img  = np.load(img_path)
    mask = np.load(mask_path)
    data = dict()

    data['id'] = Path(img_path).name
    data['img_min']  = np.min(img)
    data['img_max']  = np.max(img)
    data['img_mean'] = np.mean(img)
    data['img_std']  = np.std(img)

    data['msk_min'] = np.min(mask)
    data['msk_max'] = np.max(mask)

    data['shape'] = img.shape
    data['img_path']  = img_path
    data['mask_path'] = mask_path
    df.append(data)


df = pd.DataFrame(df)
print(df.img_path.iloc[2])
df
# Out:
# 220it [00:01, 178.85it/s]
# /home/grva-mint/Projects/Falhas/Dataset/marlim_opt/images/img_0002.npy
#                id   img_min   img_max  img_mean   img_std  msk_min  msk_max  \
# 0    img_0000.npy  0.000000  0.866501  0.500047  0.100452        0        1
# 1    img_0001.npy  0.000000  0.841332  0.500000  0.059265        0        1
# 2    img_0002.npy  0.000000  1.000000  0.494206  0.175541        0        1
# 3    img_0003.npy  0.392360  0.598597  0.500000  0.021345        0        0
# 4    img_0004.npy  0.363844  0.623932  0.500000  0.021596        0        0
# ..            ...       ...       ...       ...       ...      ...      ...
# 215  img_0215.npy  0.000000  1.000000  0.500000  0.082731        0        1
# 216  img_0216.npy  0.000000  1.000000  0.503161  0.196629        0        1
# 217  img_0217.npy  0.000000  1.000000  0.507406  0.233453        0        1
# 218  img_0218.npy  0.000000  1.000000  0.500167  0.170459        0        1
# 219  img_0219.npy  0.000000  1.000000  0.493231  0.168006        0        1
#
#                shape                                           img_path  \
# 0    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 1    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 2    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 3    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 4    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# ..               ...                                                ...
# 215  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 216  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 217  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 218  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 219  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
#
#                                              mask_path
# 0    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 1    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 2    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 3    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 4    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# ..                                                 ...
# 215  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 216  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 217  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 218  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 219  /home/grva-mint/Projects/Falhas/Dataset/marlim...
#
# [220 rows x 10 columns]

# %%
if OPTIONS.get('img_size') is None:
    df.to_csv('../DataBase.csv', index=None)
    display(df)
    sys.exit("Finalizando o programa: sem tiles nessa rodada")
# Out:
#                id   img_min   img_max  img_mean   img_std  msk_min  msk_max  \
# 0    img_0000.npy  0.000000  0.866501  0.500047  0.100452        0        1
# 1    img_0001.npy  0.000000  0.841332  0.500000  0.059265        0        1
# 2    img_0002.npy  0.000000  1.000000  0.494206  0.175541        0        1
# 3    img_0003.npy  0.392360  0.598597  0.500000  0.021345        0        0
# 4    img_0004.npy  0.363844  0.623932  0.500000  0.021596        0        0
# ..            ...       ...       ...       ...       ...      ...      ...
# 215  img_0215.npy  0.000000  1.000000  0.500000  0.082731        0        1
# 216  img_0216.npy  0.000000  1.000000  0.503161  0.196629        0        1
# 217  img_0217.npy  0.000000  1.000000  0.507406  0.233453        0        1
# 218  img_0218.npy  0.000000  1.000000  0.500167  0.170459        0        1
# 219  img_0219.npy  0.000000  1.000000  0.493231  0.168006        0        1
#
#                shape                                           img_path  \
# 0    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 1    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 2    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 3    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 4    (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# ..               ...                                                ...
# 215  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 216  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 217  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 218  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 219  (128, 128, 128)  /home/grva-mint/Projects/Falhas/Dataset/marlim...
#
#                                              mask_path
# 0    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 1    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 2    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 3    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 4    /home/grva-mint/Projects/Falhas/Dataset/marlim...
# ..                                                 ...
# 215  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 216  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 217  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 218  /home/grva-mint/Projects/Falhas/Dataset/marlim...
# 219  /home/grva-mint/Projects/Falhas/Dataset/marlim...
#
# [220 rows x 10 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Finalizando o programa: sem tiles nessa rodada
# /home/grva-mint/anaconda3/envs/torch-gpu/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # TILES

# %%
IMG_SIZE = tuple(OPTIONS['img_size'])
IMG_SIZE
# Out:
# (4, 128, 128)

# %%
class TilesBuilder:
    def __init__(self, target_size=(8, 64, 128), main_dir='tiles'):
        self.target_size = target_size
        self.main_dir    = main_dir

        if os.path.exists(main_dir):
            shutil.rmtree(main_dir)
        os.makedirs(main_dir)

    def update(self, file_path, target_dir, is_mask=False):
        folder = os.path.join(self.main_dir, target_dir)
        os.makedirs(folder, exist_ok=True)

        data = getDAT(file_path)
        base_name     = os.path.splitext(os.path.basename(file_path))[0]
        z_t, y_t, x_t = self.target_size
        
        z_pad = (z_t - data.shape[0] % z_t) % z_t
        y_pad = (y_t - data.shape[1] % y_t) % y_t
        x_pad = (x_t - data.shape[2] % x_t) % x_t

        pad_mode    = 'constant' if is_mask else 'reflect'
        data_padded = np.pad(data, ((0, z_pad), (0, y_pad), (0, x_pad)), mode=pad_mode) if z_pad > 0 or y_pad > 0 or x_pad > 0 else data
            
        index = 0
        for z in range(0, data_padded.shape[0], z_t):
            for y in range(0, data_padded.shape[1], y_t):
                for x in range(0, data_padded.shape[2], x_t):
                    tile = data_padded[z:z+z_t, y:y+y_t, x:x+x_t]
                    save_path = os.path.join(folder, f'{base_name}_tile_{index}.npy')
                    
                    np.save(save_path, tile)
                    index = (index + 1)


tiles = TilesBuilder(target_size=IMG_SIZE, main_dir='tiles')
for img_path, mask_path in tqdm(zip(images, masks), total=len(df)):
    tiles.update(img_path,  'images/', is_mask=False)
    tiles.update(mask_path, 'masks/',  is_mask=True)
# Out:
# 100%|██████████| 220/220 [00:02<00:00, 89.92it/s]

# %%
print(len(getFiles('tiles/images')), 'imagens geradas')
# Out:
# 7040 imagens geradas

# %%
df = pd.DataFrame()
df['img_path'] = [file for file in getFiles('tiles/images')]
df['mask_path'] = [file for file in getFiles('tiles/masks')]
df['shape']    = [(128, 128, 128) for path in df.img_path]
df['min']  = [np.min(getDAT(path))  for path in df.img_path]
df['max']  = [np.max(getDAT(path))  for path in df.img_path]
df['mean'] = [np.mean(getDAT(path)) for path in df.img_path]
df['std']  = [np.std(getDAT(path))  for path in df.img_path]

print(df.img_path.iloc[2])
df.to_csv('../DataBase.csv', index=None)
df
# Out:
#                                             img_path  \
# 0      ../Dataset/dataset0/tiles/images/0_tile_0.npy
# 1      ../Dataset/dataset0/tiles/images/0_tile_1.npy
# 2     ../Dataset/dataset0/tiles/images/0_tile_10.npy
# 3     ../Dataset/dataset0/tiles/images/0_tile_11.npy
# 4     ../Dataset/dataset0/tiles/images/0_tile_12.npy
# ...                                              ...
# 7035   ../Dataset/dataset0/tiles/images/9_tile_5.npy
# 7036   ../Dataset/dataset0/tiles/images/9_tile_6.npy
# 7037   ../Dataset/dataset0/tiles/images/9_tile_7.npy
# 7038   ../Dataset/dataset0/tiles/images/9_tile_8.npy
# 7039   ../Dataset/dataset0/tiles/images/9_tile_9.npy
#
#                                           mask_path          shape
# 0      ../Dataset/dataset0/tiles/masks/0_tile_0.npy  (4, 128, 128)
# 1      ../Dataset/dataset0/tiles/masks/0_tile_1.npy  (4, 128, 128)
# 2     ../Dataset/dataset0/tiles/masks/0_tile_10.npy  (4, 128, 128)
# 3     ../Dataset/dataset0/tiles/masks/0_tile_11.npy  (4, 128, 128)
# 4     ../Dataset/dataset0/tiles/masks/0_tile_12.npy  (4, 128, 128)
# ...                                             ...            ...
# 7035   ../Dataset/dataset0/tiles/masks/9_tile_5.npy  (4, 128, 128)
# 7036   ../Dataset/dataset0/tiles/masks/9_tile_6.npy  (4, 128, 128)
# 7037   ../Dataset/dataset0/tiles/masks/9_tile_7.npy  (4, 128, 128)
# 7038   ../Dataset/dataset0/tiles/masks/9_tile_8.npy  (4, 128, 128)
# 7039   ../Dataset/dataset0/tiles/masks/9_tile_9.npy  (4, 128, 128)
#
# [7040 rows x 3 columns]
