# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
OPTIONS =  json.loads(open('config.json', 'r').read())
OPTIONS
# Out:
# {'layerRange': [54, 327],
#  'layerThickness': [1, 5],
#  'foldCount': [19, 52],
#  'foldSigma': [14, 48],
#  'foldAmplitude': [-32, 8],
#  'foldDamping': 0.7504553653965067,
#  'foldBaseShift': [-0.42035888288475476, 4.97111957122141],
#  'shearOffset': [-8.46102976148038, 4.645130840170387],
#  'shearGradient': [-0.12517485336038706, 0.024790224015204997],
#  'faultCount': [4, 10],
#  'faultThrow': [13, 32],
#  'faultDipAngle': [57, 80],
#  'faultRoughness': 6.5018273671807,
#  'faultRoughSigma': 7.307322856129061,
#  'faultDecaySigma': [47, 69],
#  'faultZoneWidth': 1.0873938523051598,
#  'faultThreshold': 0.6397512407902599,
#  'faultCurveProb': 0.42195950662202736,
#  'faultCurveMax': 4.9151448716568265,
#  'waveletFreq': [86, 91],
#  'waveletDuration': 0.09582668881736313,
#  'waveletDt': 0.0019311423937286827,
#  'noiseLevel': [0.011914250332247743, 0.6305055604667738]}

# %%
dataset = 'dataset_synthetic'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(OPTIONS, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator(seed=42)
    gen.set(OPTIONS)
    gen.dataset(n=220, outputDir=f'../Dataset/{dataset}/original')
# Out:
# random seed done
# Generating dataset:   0%|                               | 0/220 [00:00<?, ?it/s]
# Generating dataset:   0%|                    | 1/220 [02:23<8:43:06, 143.32s/it]
# Generating dataset:   9%|██                    | 20/220 [02:23<17:00,  5.10s/it]
# Generating dataset:   9%|██                    | 20/220 [02:40<17:00,  5.10s/it]
# Generating dataset:  10%|██                    | 21/220 [03:30<30:49,  9.29s/it]
# Generating dataset:  12%|██▋                   | 27/220 [03:33<19:32,  6.08s/it]
# Generating dataset:  15%|███▏                  | 32/220 [03:49<16:12,  5.17s/it]
# Generating dataset:  15%|███▎                  | 33/220 [04:06<19:13,  6.17s/it]
# Generating dataset:  18%|███▉                  | 39/220 [04:21<13:58,  4.63s/it]
# Generating dataset:  18%|████                  | 40/220 [04:34<16:18,  5.44s/it]
# Generating dataset:  19%|████▏                 | 42/220 [04:45<15:53,  5.36s/it]
# Generating dataset:  21%|████▌                 | 46/220 [04:56<12:48,  4.41s/it]
# Generating dataset:  22%|████▊                 | 48/220 [05:22<17:46,  6.20s/it]
# Generating dataset:  23%|█████                 | 50/220 [05:31<16:26,  5.80s/it]
# Generating dataset:  24%|█████▎                | 53/220 [05:41<14:05,  5.06s/it]
# Generating dataset:  25%|█████▌                | 56/220 [05:51<12:14,  4.48s/it]
# Generating dataset:  25%|█████▌                | 56/220 [06:10<12:14,  4.48s/it]
# Generating dataset:  27%|██████                | 60/220 [06:15<13:20,  5.01s/it]
# Generating dataset:  28%|██████                | 61/220 [06:38<19:09,  7.23s/it]
# Generating dataset:  29%|██████▍               | 64/220 [06:47<14:52,  5.72s/it]
# Generating dataset:  29%|██████▍               | 64/220 [07:00<14:52,  5.72s/it]
# Generating dataset:  31%|██████▊               | 68/220 [07:00<12:04,  4.76s/it]
# Generating dataset:  31%|██████▉               | 69/220 [07:18<16:13,  6.45s/it]
# Generating dataset:  34%|███████▍              | 75/220 [07:33<10:34,  4.37s/it]
# Generating dataset:  35%|███████▋              | 77/220 [07:45<11:14,  4.72s/it]
# Generating dataset:  36%|███████▉              | 79/220 [07:52<10:35,  4.51s/it]
# Generating dataset:  37%|████████▏             | 82/220 [08:07<10:43,  4.66s/it]
# Generating dataset:  38%|████████▍             | 84/220 [08:28<13:40,  6.03s/it]
# Generating dataset:  39%|████████▌             | 86/220 [08:43<14:07,  6.32s/it]
# Generating dataset:  40%|████████▊             | 88/220 [08:50<12:21,  5.62s/it]
# Generating dataset:  43%|█████████▌            | 95/220 [08:52<05:19,  2.56s/it]
# Generating dataset:  44%|█████████▌            | 96/220 [09:18<10:25,  5.05s/it]
# Generating dataset:  45%|█████████▊            | 98/220 [09:25<09:27,  4.65s/it]
# Generating dataset:  46%|█████████▋           | 101/220 [09:34<08:06,  4.09s/it]
# Generating dataset:  46%|█████████▋           | 102/220 [09:46<10:19,  5.25s/it]
# Generating dataset:  48%|██████████           | 105/220 [09:56<08:44,  4.56s/it]
# Generating dataset:  48%|██████████           | 106/220 [10:20<13:57,  7.34s/it]
# Generating dataset:  50%|██████████▍          | 109/220 [10:23<09:05,  4.92s/it]
# Generating dataset:  50%|██████████▍          | 109/220 [10:28<10:39,  5.77s/it]
