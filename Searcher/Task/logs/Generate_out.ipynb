# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
OPTIONS =  json.loads(open('config.json', 'r').read())
OPTIONS
# Out:
# {'layerRange': [28, 228],
#  'layerThickness': [1, 2],
#  'foldCount': [18, 47],
#  'foldSigma': [15, 41],
#  'foldAmplitude': [-35, 10],
#  'foldDamping': 1.0800424794321366,
#  'foldBaseShift': [-0.8450576845472607, 4.562931704793572],
#  'shearOffset': [-7.629669981516424, 2.847542046642918],
#  'shearGradient': [-0.10969979211435178, 0.011495501857785174],
#  'faultCount': [4, 9],
#  'faultThrow': [15, 37],
#  'faultDipAngle': [51, 78],
#  'faultRoughness': 3.3206626215744657,
#  'faultRoughSigma': 9.711163264246792,
#  'faultDecaySigma': [52, 57],
#  'faultZoneWidth': 1.0372903423877278,
#  'faultThreshold': 0.7411092023023325,
#  'faultCurveProb': 0.005445586122473509,
#  'faultCurveMax': 6.955855650706256,
#  'waveletFreq': [82, 96],
#  'waveletDuration': 0.11427777463926023,
#  'waveletDt': 0.001907584244149895,
#  'noiseLevel': [0.01899299842941636, 0.6116176644041454]}

# %%
dataset = 'dataset_synthetic'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(OPTIONS, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator(seed=42)
    gen.set(OPTIONS)
    gen.dataset(n=220, outputDir=f'../Dataset/{dataset}/original')
# Out:
# random seed done
# Generating dataset:   0%|                                                                                                       | 0/220 [00:00<?, ?it/s]
# Generating dataset:   0%|▍                                                                                           | 1/220 [01:55<7:03:05, 115.92s/it]
# Generating dataset:   1%|█▎                                                                                           | 3/220 [02:09<2:07:19, 35.20s/it]
# Generating dataset:   7%|██████▊                                                                                       | 16/220 [02:10<15:24,  4.53s/it]
# Generating dataset:   7%|██████▊                                                                                       | 16/220 [02:30<15:24,  4.53s/it]
# Generating dataset:  10%|████████▉                                                                                     | 21/220 [03:16<24:12,  7.30s/it]
# Generating dataset:  10%|█████████▍                                                                                    | 22/220 [03:20<23:08,  7.01s/it]
# Generating dataset:  10%|█████████▊                                                                                    | 23/220 [03:29<23:47,  7.25s/it]
# Generating dataset:  12%|███████████                                                                                   | 26/220 [03:35<18:03,  5.58s/it]
# Generating dataset:  15%|█████████████▋                                                                                | 32/220 [03:36<09:34,  3.06s/it]
