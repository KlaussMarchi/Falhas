# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
OPTIONS =  json.loads(open('config.json', 'r').read())
OPTIONS
# Out:
# {'layerRange': [13, 281],
#  'layerThickness': [1, 5],
#  'foldCount': [18, 44],
#  'foldSigma': [15, 73],
#  'foldAmplitude': [-34, 8],
#  'foldDamping': 1.3754310868740631,
#  'foldBaseShift': [-0.5627467171762, 4.190844959550284],
#  'shearOffset': [-8.092603552442466, 4.465700619976732],
#  'shearGradient': [-0.09577415742227978, 0.011398482375105304],
#  'faultCount': [4, 7],
#  'faultThrow': [13, 37],
#  'faultDipAngle': [63, 82],
#  'faultRoughness': 4.033248701957904,
#  'faultRoughSigma': 9.763352997498933,
#  'faultDecaySigma': [47, 48],
#  'faultZoneWidth': 1.1265989732687107,
#  'faultThreshold': 0.8155687762612178,
#  'faultCurveProb': 0.0842041834077859,
#  'faultCurveMax': 10.406447723806227,
#  'waveletFreq': [62, 110],
#  'waveletDuration': 0.10087909388838766,
#  'waveletDt': 0.0009540102824207003,
#  'noiseLevel': [0.012152083556654427, 0.6078350248191675]}

# %%
dataset = 'dataset_synthetic'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(OPTIONS, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator(seed=42)
    gen.set(OPTIONS)
    gen.dataset(n=220, outputDir=f'../Dataset/{dataset}/original')
# Out:
# random seed done
# Generating dataset:   0%|                                                                                                                  | 0/220 [00:00<?, ?it/s]
# Generating dataset:   0%|▍                                                                                                      | 1/220 [01:46<6:29:04, 106.60s/it]
# Generating dataset:  10%|██████████                                                                                               | 21/220 [02:45<21:22,  6.44s/it]
# Generating dataset:  10%|██████████▌                                                                                              | 22/220 [02:49<20:47,  6.30s/it]
# Generating dataset:  10%|██████████▉                                                                                              | 23/220 [02:51<19:28,  5.93s/it]
# Generating dataset:  11%|███████████▍                                                                                             | 24/220 [02:54<18:17,  5.60s/it]
# Generating dataset:  12%|████████████▉                                                                                            | 27/220 [02:57<13:15,  4.12s/it]
# Generating dataset:  13%|█████████████▎                                                                                           | 28/220 [03:01<13:17,  4.15s/it]
# Generating dataset:  13%|█████████████▊                                                                                           | 29/220 [03:03<12:05,  3.80s/it]
# Generating dataset:  15%|████████████████▏                                                                                        | 34/220 [03:04<06:00,  1.94s/it]
# Generating dataset:  16%|████████████████▋                                                                                        | 35/220 [03:08<06:49,  2.21s/it]
# Generating dataset:  17%|██████████████████▏                                                                                      | 38/220 [03:16<06:57,  2.29s/it]
# Generating dataset:  19%|███████████████████▌                                                                                     | 41/220 [03:56<18:00,  6.04s/it]
# Generating dataset:  19%|████████████████████                                                                                     | 42/220 [04:17<24:21,  8.21s/it]
