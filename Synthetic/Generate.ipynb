# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
best_options = {
        "layerRange": [
            26,
            240
        ],
        "layerThickness": [
            1,
            4
        ],
        "foldCount": [
            15,
            46
        ],
        "foldSigma": [
            16,
            62
        ],
        "foldAmplitude": [
            -34,
            10
        ],
        "foldDamping": 1.4366631303648751,
        "foldBaseShift": [
            -0.9154641806006353,
            4.794895268713025
        ],
        "shearOffset": [
            -8.603805371099348,
            3.1700647174932515
        ],
        "shearGradient": [
            -0.09796281018523263,
            0.014488832586227747
        ],
        "faultCount": [
            5,
            10
        ],
        "faultThrow": [
            15,
            32
        ],
        "faultDipAngle": [
            62,
            82
        ],
        "faultRoughness": 3.125214925093391,
        "faultRoughSigma": 8.647726493231612,
        "faultDecaySigma": [
            45,
            52
        ],
        "faultZoneWidth": 1.0046112593875955,
        "faultThreshold": 0.7487165217234115,
        "faultCurveProb": 0.0128856391225712,
        "faultCurveMax": 8.699330303845256,
        "waveletFreq": [
            61,
            105
        ],
        "waveletDuration": 0.10272217673381287,
        "waveletDt": 0.0012098788056885896,
        "noiseLevel": [
            0.0180086846411557,
            0.607073807109545
        ]
    }

# %%
gen = SyntheticGenerator()
gen.set(best_options)
gen.print()

for i in range(5):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         26,
#         240
#     ],
#     "layerThickness": [
#         1,
#         4
#     ],
#     "foldCount": [
#         15,
#         46
#     ],
#     "foldSigma": [
#         16,
#         62
#     ],
#     "foldAmplitude": [
#         -34,
#         10
#     ],
#     "foldDamping": 1.4366631303648751,
#     "foldBaseShift": [
#         -0.9154641806006353,
#         4.794895268713025
#     ],
#     "shearOffset": [
#         -8.603805371099348,
#         3.1700647174932515
#     ],
#     "shearGradient": [
#         -0.09796281018523263,
#         0.014488832586227747
#     ],
#     "faultCount": [
#         5,
#         10
#     ],
#     "faultThrow": [
#         15,
#         32
#     ],
#     "faultDipAngle": [
#         62,
#         82
#     ],
#     "faultRoughness": 3.125214925093391,
#     "faultRoughSigma": 8.647726493231612,
#     "faultDecaySigma": [
#         45,
#         52
#     ],
#     "faultZoneWidth": 1.0046112593875955,
#     "faultThreshold": 0.7487165217234115,
#     "faultCurveProb": 0.0128856391225712,
#     "faultCurveMax": 8.699330303845256,
#     "waveletFreq": [
#         61,
#         105
#     ],
#     "waveletDuration": 0.10272217673381287,
#     "waveletDt": 0.0012098788056885896,
#     "noiseLevel": [
#         0.0180086846411557,
#         0.607073807109545
#     ]
# }
# showing img 0
# showing img 1
# showing img 2
# showing img 3
# showing img 4

# %%
dataset = 'dataset_72'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(best_options, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator(seed=42)
    gen.set(best_options)
    gen.dataset(n=220, outputDir=f'../Dataset/{dataset}/original')
# Out:
# random seed done
# Generating dataset: 100%|██████████| 220/220 [20:50<00:00,  5.68s/it]
