# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
best_options = {
    "layerRange": [
        72,
        154
    ],
    "layerThickness": [
        1,
        7
    ],
    "foldCount": [
        12,
        26
    ],
    "foldSigma": [
        7,
        74
    ],
    "foldAmplitude": [
        -28,
        34
    ],
    "foldDamping": 2.729108861461884,
    "foldBaseShift": [
        -0.846091274399015,
        2.9883234275397896
    ],
    "shearOffset": [
        -1.5974688247171969,
        4.808438156341225
    ],
    "shearGradient": [
        -0.3992332906561768,
        0.23740125496512832
    ],
    "faultCount": [
        0,
        8
    ],
    "faultThrow": [
        3,
        36
    ],
    "faultDipAngle": [
        54,
        89
    ],
    "faultRoughness": 2.323079447168227,
    "faultRoughSigma": 5.614677961692463,
    "faultDecaySigma": [
        9,
        119
    ],
    "faultZoneWidth": 0.9495823003844502,
    "faultThreshold": 0.9302376560072076,
    "faultCurveProb": 0.5680622818868736,
    "faultCurveMax": 6.09612048417798,
    "waveletFreq": [
        94,
        196
    ],
    "waveletDuration": 0.1823062465329696,
    "waveletDt": 0.011627765614647673,
    "noiseLevel": [
        0.0,
        0.3
    ]
}

# %%
gen = SyntheticGenerator()
gen.set(best_options)
gen.print()

for i in range(5):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         72,
#         154
#     ],
#     "layerThickness": [
#         1,
#         7
#     ],
#     "foldCount": [
#         12,
#         26
#     ],
#     "foldSigma": [
#         7,
#         74
#     ],
#     "foldAmplitude": [
#         -28,
#         34
#     ],
#     "foldDamping": 2.729108861461884,
#     "foldBaseShift": [
#         -0.846091274399015,
#         2.9883234275397896
#     ],
#     "shearOffset": [
#         -1.5974688247171969,
#         4.808438156341225
#     ],
#     "shearGradient": [
#         -0.3992332906561768,
#         0.23740125496512832
#     ],
#     "faultCount": [
#         0,
#         8
#     ],
#     "faultThrow": [
#         3,
#         36
#     ],
#     "faultDipAngle": [
#         54,
#         89
#     ],
#     "faultRoughness": 2.323079447168227,
#     "faultRoughSigma": 5.614677961692463,
#     "faultDecaySigma": [
#         9,
#         119
#     ],
#     "faultZoneWidth": 0.9495823003844502,
#     "faultThreshold": 0.9302376560072076,
#     "faultCurveProb": 0.5680622818868736,
#     "faultCurveMax": 6.09612048417798,
#     "waveletFreq": [
#         94,
#         196
#     ],
#     "waveletDuration": 0.1823062465329696,
#     "waveletDt": 0.011627765614647673,
#     "noiseLevel": [
#         0.0,
#         0.3
#     ]
# }
# showing img 0
# showing img 1
# showing img 2
# showing img 3
# showing img 4

# %%
dataset = 'dataset7'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(best_options, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator()
    gen.set(best_options)
    gen.dataset(n=220, outputDir=f'../Dataset/{dataset}/original')
# Out:
# Generating dataset: 100%|██████████| 220/220 [20:34<00:00,  5.61s/it]
