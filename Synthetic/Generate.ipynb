# %%
import os
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from utils import *
from index import SyntheticGenerator

# %%
best_options = {
    "layerRange": [
        59,
        293
    ],
    "layerThickness": [
        2,
        3
    ],
    "foldCount": [
        7,
        29
    ],
    "foldSigma": [
        17,
        38
    ],
    "foldAmplitude": [
        -8,
        14
    ],
    "foldDamping": 1.9652891134338613,
    "foldBaseShift": [
        -1.7817678515388828,
        1.7247333198050963
    ],
    "shearOffset": [
        -3.9812052831914704,
        1.711522334413226
    ],
    "shearGradient": [
        -0.09685666356598369,
        0.1563808918844276
    ],
    "faultCount": [
        4,
        7
    ],
    "faultThrow": [
        5,
        25
    ],
    "faultDipAngle": [
        49,
        82
    ],
    "faultRoughness": 2.32249458174305,
    "faultRoughSigma": 3.0014368447712862,
    "faultDecaySigma": [
        34,
        83
    ],
    "faultZoneWidth": 1.0219748559945656,
    "faultThreshold": 0.6992326649782601,
    "faultCurveProb": 0.24581120923818361,
    "faultCurveMax": 3.1492397419531653,
    "waveletFreq": [
        69,
        97
    ],
    "waveletDuration": 0.06604178041012981,
    "waveletDt": 0.009708596957033785,
    "noiseLevel": [
        0,
        0.15563172083662333
    ]
}

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
gen = SyntheticGenerator()
gen.set(best_options)
gen.print()

for i in range(5):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         59,
#         293
#     ],
#     "layerThickness": [
#         2,
#         3
#     ],
#     "foldCount": [
#         7,
#         29
#     ],
#     "foldSigma": [
#         17,
#         38
#     ],
#     "foldAmplitude": [
#         -8,
#         14
#     ],
#     "foldDamping": 1.9652891134338613,
#     "foldBaseShift": [
#         -1.7817678515388828,
#         1.7247333198050963
#     ],
#     "shearOffset": [
#         -3.9812052831914704,
#         1.711522334413226
#     ],
#     "shearGradient": [
#         -0.09685666356598369,
#         0.1563808918844276
#     ],
#     "faultCount": [
#         4,
#         7
#     ],
#     "faultThrow": [
#         5,
#         25
#     ],
#     "faultDipAngle": [
#         49,
#         82
#     ],
#     "faultRoughness": 2.32249458174305,
#     "faultRoughSigma": 3.0014368447712862,
#     "faultDecaySigma": [
#         34,
#         83
#     ],
#     "faultZoneWidth": 1.0219748559945656,
#     "faultThreshold": 0.6992326649782601,
#     "faultCurveProb": 0.24581120923818361,
#     "faultCurveMax": 3.1492397419531653,
#     "waveletFreq": [
#         69,
#         97
#     ],
#     "waveletDuration": 0.06604178041012981,
#     "waveletDt": 0.009708596957033785,
#     "noiseLevel": [
#         0,
#         0.15563172083662333
#     ]
# }
# showing img 0
# showing img 1
# showing img 2
# showing img 3
# showing img 4

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator()
    gen.set(best_options)
    gen.dataset(n=220, outputDir='../Dataset/dataset3/original')
# Out:
# Generating dataset: 100%|██████████| 220/220 [20:55<00:00,  5.71s/it]
