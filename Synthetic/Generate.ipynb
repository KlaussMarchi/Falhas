# %%
import os
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from utils import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
best_options = {
    "faultDipAngle": [46, 83],
    "noiseLevel": [0, 0.4],
    "layerRange": [60, 300],
    "waveletDt": 0.008778821109769894,
    "faultZoneWidth": 1.0349433151902085,
    "faultThreshold": 0.855810,
    "faultCurveProb": 0.195110,
    "faultCurveMax": 3.93769,
    "faultZoneWidth": 1.034943,
    "waveletFreq": [90, 136]
}

# %%
gen = SyntheticGenerator()
gen.set(best_options)
gen.print()

for i in range(5):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         60,
#         300
#     ],
#     "layerThickness": [
#         1,
#         2
#     ],
#     "foldCount": [
#         15,
#         30
#     ],
#     "foldSigma": [
#         8,
#         44
#     ],
#     "foldAmplitude": [
#         -17,
#         17
#     ],
#     "foldDamping": 1.5,
#     "foldBaseShift": [
#         -1.6,
#         1.6
#     ],
#     "shearOffset": [
#         -2.8,
#         2.8
#     ],
#     "shearGradient": [
#         -0.1,
#         0.1
#     ],
#     "faultCount": [
#         4,
#         7
#     ],
#     "faultThrow": [
#         0,
#         22
#     ],
#     "faultDipAngle": [
#         46,
#         83
#     ],
#     "faultRoughness": 3.3,
#     "faultRoughSigma": 4.5,
#     "faultDecaySigma": [
#         33,
#         83
#     ],
#     "faultZoneWidth": 1.034943,
#     "faultThreshold": 0.85581,
#     "faultCurveProb": 0.19511,
#     "faultCurveMax": 3.93769,
#     "waveletFreq": [
#         90,
#         136
#     ],
#     "waveletDuration": 0.08,
#     "waveletDt": 0.008778821109769894,
#     "noiseLevel": [
#         0,
#         0.4
#     ]
# }
# showing img 0
# showing img 1
# showing img 2
# showing img 3
# showing img 4

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator()
    gen.set(best_options)
    gen.dataset(n=400, outputDir='../Dataset/dataset6/original')
# Out:
# Generating dataset: 100%|██████████| 400/400 [36:13<00:00,  5.43s/it]
