# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
best_options = {"layerRange": [71, 212], "layerThickness": [1, 5], "foldCount": [11, 49], "foldSigma": [9, 65], "foldAmplitude": [-23, 5], "foldDamping": 1.644532681792406, "foldBaseShift": [-1.0028218787780756, 3.2735195006591695], "shearOffset": [-6.051288303482915, 3.4051323096496997], "shearGradient": [-0.0950267719011634, 0.027231745589120004], "faultCount": [4, 7], "faultThrow": [6, 32], "faultDipAngle": [47, 77], "faultRoughness": 3.8929843871806966, "faultRoughSigma": 5.541366415586716, "faultDecaySigma": [40, 94], "faultZoneWidth": 0.9872105556345617, "faultThreshold": 0.8214749796701698, "faultCurveProb": 0.26637511436865025, "faultCurveMax": 3.1809750822652973, "waveletFreq": [67, 188], "waveletDuration": 0.06111488905680998, "waveletDt": 0.0019709476224890362, "noiseLevel": [0.0, 0.297747619882763]}

# %%
gen = SyntheticGenerator()
gen.set(best_options)
gen.print()

for i in range(5):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         71,
#         212
#     ],
#     "layerThickness": [
#         1,
#         5
#     ],
#     "foldCount": [
#         11,
#         49
#     ],
#     "foldSigma": [
#         9,
#         65
#     ],
#     "foldAmplitude": [
#         -23,
#         5
#     ],
#     "foldDamping": 1.644532681792406,
#     "foldBaseShift": [
#         -1.0028218787780756,
#         3.2735195006591695
#     ],
#     "shearOffset": [
#         -6.051288303482915,
#         3.4051323096496997
#     ],
#     "shearGradient": [
#         -0.0950267719011634,
#         0.027231745589120004
#     ],
#     "faultCount": [
#         4,
#         7
#     ],
#     "faultThrow": [
#         6,
#         32
#     ],
#     "faultDipAngle": [
#         47,
#         77
#     ],
#     "faultRoughness": 3.8929843871806966,
#     "faultRoughSigma": 5.541366415586716,
#     "faultDecaySigma": [
# ...

# %%
dataset = 'dataset3'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(best_options, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator()
    gen.set(best_options)
    gen.dataset(n=110, outputDir=f'../Dataset/{dataset}/original')
# Out:
# Generating dataset:  73%|███████▎  | 80/110 [19:15<04:13,  8.44s/it]
