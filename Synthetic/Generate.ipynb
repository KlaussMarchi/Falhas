# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
best_options = {
        "layerRange": [
            67,
            179
        ],
        "layerThickness": [
            1,
            2
        ],
        "foldCount": [
            18,
            51
        ],
        "foldSigma": [
            21,
            63
        ],
        "foldAmplitude": [
            -35,
            6
        ],
        "foldDamping": 1.4256662610750612,
        "foldBaseShift": [
            -0.5803132592641779,
            3.1723954854523826
        ],
        "shearOffset": [
            -8.365533221407572,
            3.591709444720005
        ],
        "shearGradient": [
            -0.11137220627207978,
            0.022624650531647358
        ],
        "faultCount": [
            3,
            8
        ],
        "faultThrow": [
            16,
            39
        ],
        "faultDipAngle": [
            67,
            81
        ],
        "faultRoughness": 3.945893074372243,
        "faultRoughSigma": 5.973822073234469,
        "faultDecaySigma": [
            48,
            69
        ],
        "faultZoneWidth": 1.066067532679169,
        "faultThreshold": 0.5415291973041982,
        "faultCurveProb": 0.05167879641345534,
        "faultCurveMax": 5.925503958896865,
        "waveletFreq": [
            74,
            79
        ],
        "waveletDuration": 0.1101897132147185,
        "waveletDt": 0.0017054028351836652,
        "noiseLevel": [
            0.02782830152717929,
            0.5354401914165896
        ]
    }

# %%
gen = SyntheticGenerator()
gen.set(best_options)
gen.print()

for i in range(5):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         26,
#         164
#     ],
#     "layerThickness": [
#         1,
#         4
#     ],
#     "foldCount": [
#         12,
#         39
#     ],
#     "foldSigma": [
#         21,
#         37
#     ],
#     "foldAmplitude": [
#         -35,
#         9
#     ],
#     "foldDamping": 1.4585157824914143,
#     "foldBaseShift": [
#         -0.5266587512616131,
#         3.97473347561543
#     ],
#     "shearOffset": [
#         -9.317259174030998,
#         2.645254787842478
#     ],
#     "shearGradient": [
#         -0.12197599312003501,
#         0.015128754277707417
#     ],
#     "faultCount": [
#         6,
#         12
#     ],
#     "faultThrow": [
#         14,
#         29
#     ],
#     "faultDipAngle": [
#         56,
#         79
#     ],
#     "faultRoughness": 6.965454610376137,
#     "faultRoughSigma": 9.913484743274134,
#     "faultDecaySigma": [
# ...

# %%
dataset = 'dataset_71'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(best_options, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator(seed=42)
    gen.set(best_options)
    gen.dataset(n=220, outputDir=f'../Dataset/{dataset}/original')
# Out:
# random seed done
# Generating dataset: 100%|██████████| 220/220 [1:08:57<00:00, 18.81s/it]
