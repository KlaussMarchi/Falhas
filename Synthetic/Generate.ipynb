# %%
import os, json
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from Utils.index import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
best_options = {
        "layerRange": [
            20,
            170
        ],
        "layerThickness": [
            1,
            4
        ],
        "foldCount": [
            10,
            45
        ],
        "foldSigma": [
            16,
            45
        ],
        "foldAmplitude": [
            -35,
            3
        ],
        "foldDamping": 1.4206612740372302,
        "foldBaseShift": [
            -0.6444124860258419,
            4.745977006215013
        ],
        "shearOffset": [
            -8.85535474316226,
            3.4100979011020787
        ],
        "shearGradient": [
            -0.1124023388550812,
            0.027957779321985916
        ],
        "faultCount": [
            6,
            10
        ],
        "faultThrow": [
            15,
            31
        ],
        "faultDipAngle": [
            50,
            82
        ],
        "faultRoughness": 3.387286123299896,
        "faultRoughSigma": 8.681947790504696,
        "faultDecaySigma": [
            41,
            70
        ],
        "faultZoneWidth": 0.9655776720403633,
        "faultThreshold": 0.7258149804041092,
        "faultCurveProb": 0.4985885786832633,
        "faultCurveMax": 9.443515039275246,
        "waveletFreq": [
            86,
            97
        ],
        "waveletDuration": 0.09610404171941697,
        "waveletDt": 0.0010419049051408947,
        "noiseLevel": [
            0.011732302288271566,
            0.6298197214341477
        ]
    }

# %%
gen = SyntheticGenerator()
gen.set(best_options)
gen.print()

for i in range(5):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         20,
#         170
#     ],
#     "layerThickness": [
#         1,
#         4
#     ],
#     "foldCount": [
#         10,
#         45
#     ],
#     "foldSigma": [
#         16,
#         45
#     ],
#     "foldAmplitude": [
#         -35,
#         3
#     ],
#     "foldDamping": 1.4206612740372302,
#     "foldBaseShift": [
#         -0.6444124860258419,
#         4.745977006215013
#     ],
#     "shearOffset": [
#         -8.85535474316226,
#         3.4100979011020787
#     ],
#     "shearGradient": [
#         -0.1124023388550812,
#         0.027957779321985916
#     ],
#     "faultCount": [
#         6,
#         10
#     ],
#     "faultThrow": [
#         15,
#         31
#     ],
#     "faultDipAngle": [
#         50,
#         82
#     ],
#     "faultRoughness": 3.387286123299896,
#     "faultRoughSigma": 8.681947790504696,
#     "faultDecaySigma": [
#         41,
#         70
#     ],
#     "faultZoneWidth": 0.9655776720403633,
#     "faultThreshold": 0.7258149804041092,
#     "faultCurveProb": 0.4985885786832633,
#     "faultCurveMax": 9.443515039275246,
#     "waveletFreq": [
#         86,
#         97
#     ],
#     "waveletDuration": 0.09610404171941697,
#     "waveletDt": 0.0010419049051408947,
#     "noiseLevel": [
#         0.011732302288271566,
#         0.6298197214341477
#     ]
# }
# showing img 0
# showing img 1
# showing img 2
# showing img 3
# showing img 4

# %%
dataset = 'dataset_69'
os.makedirs(f'../Dataset/{dataset}/', exist_ok=True)

with open(f'../Dataset/{dataset}/synthetic.json', 'w', encoding='utf-8') as file:
    json.dump(best_options, file, ensure_ascii=False, indent=4)

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator(seed=42)
    gen.set(best_options)
    gen.dataset(n=220, outputDir=f'../Dataset/{dataset}/original')
# Out:
# random seed done
# Generating dataset: 100%|██████████| 220/220 [21:33<00:00,  5.88s/it]
