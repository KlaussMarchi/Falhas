# %%
import os
import shutil
shutil.rmtree('__pycache__', ignore_errors=True)

from utils import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
gen = SyntheticGenerator()
gen.print()

for i in range(10):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)
    
    showTile(image)
    showTile(image, mask)
    print('\n\n')
# Out:
# {
#     "shape": [
#         256,
#         256,
#         256
#     ],
#     "margin": 64,
#     "layerRange": [
#         100,
#         230
#     ],
#     "layerThickness": [
#         1,
#         2
#     ],
#     "foldCount": [
#         15,
#         30
#     ],
#     "foldSigma": [
#         8,
#         44
#     ],
#     "foldAmplitude": [
#         -17,
#         17
#     ],
#     "foldDamping": 1.5,
#     "foldBaseShift": [
#         -1.6,
#         1.6
#     ],
#     "shearOffset": [
#         -2.8,
#         2.8
#     ],
#     "shearGradient": [
#         -0.1,
#         0.1
#     ],
#     "faultCount": [
#         4,
#         7
#     ],
#     "faultThrow": [
#         0,
#         22
#     ],
#     "faultDipAngle": [
#         20,
#         75
#     ],
#     "faultRoughness": 3.3,
#     "faultRoughSigma": 4.5,
#     "faultDecaySigma": [
#         33,
#         83
#     ],
#     "faultZoneWidth": 1.2,
#     "faultThreshold": 0.8,
#     "faultCurveProb": 0.3,
#     "faultCurveMax": 6.7,
#     "waveletFreq": [
#         81,
#         117
#     ],
#     "waveletDuration": 0.08,
#     "waveletDt": 0.002,
#     "noiseLevel": [
#         0.0,
#         0.1
#     ]
# }
# showing img 0
# showing img 1
# showing img 2
# showing img 3
# showing img 4

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator()
    gen.dataset(n=50, outputDir='../Dataset/dataset4/original')
# Out:
# Generating dataset: 100%|██████████| 50/50 [21:52<00:00, 26.25s/it]
