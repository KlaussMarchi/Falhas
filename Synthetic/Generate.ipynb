# %%
from utils import *
from index import SyntheticGenerator

# %% [markdown]
# ### Variáveis que melhoram a qualidade/nitidez
# - self.waveletFreq = (45, 65)    # Frequência alta = nitidez
# - self.noiseLevel = (0.0, 0.01)  # Quase zero ruído
# - self.layerThickness = (1, 3)   # Camadas finas
# - self.faultRoughness = 1.0      # Falhas mais limpas e retas

# %%
gen = SyntheticGenerator()
gen.prepare()

for i in range(2):
    print('showing img', i)
    image, mask = gen.get()    
    image, mask = formatAxis(image), formatAxis(mask)

    showTile(image)
    showTile(mask, mask=True)
    print('\n\n')
# Out:
# showing img 0
# showing img 1

# %% [markdown]
# # APLICANDO DATASET

# %%
SAVE_DATA = True

# %%
if SAVE_DATA:
    gen = SyntheticGenerator()
    gen.dataset(n=50, outputDir='../Dataset/dataset3/original')
# Out:
# Generating dataset: 100%|██████████| 50/50 [1:06:32<00:00, 79.84s/it]
